# %%
#Import dask
import dask.dataframe as dd

# %%
#Specify metatype to faster analysis
types = {'camino': str, 'organismo_nombre': str, 'organismo_codigo': str, 'fecha_publicacion': str,
       'anyo': str, 'Mes': str, 'nombre': str, 'Tipo cargo': str, 'grado_eus': str,
       'tipo_calificacionp': str, 'region': str, 'asignaciones': str, 'Tipo Unidad monetaria': str,
       'remuneracionbruta_mensual': float, 'remuliquida_mensual': float, 'diurnas': str,
       'nocturnas': str, 'fecha_ingreso': str, 'fecha_termino': str, 'observaciones': str,
       'viaticos': str, 'enlace': str}


types2 = {'camino' : str,
'organismo_nombre' : str,
'organismo_codigo' : str,
'fecha_publicacion' : str,
'anyo' : str,
'Mes' : str,
'Tipo' : str,
'Estamento' : str,
'Nombres' : str,
'Paterno' : str,
'Materno' : str,
'grado_eus' : str,
'tipo_calificacionp' : str,
'Tipo cargo' : str,
'region' : str,
'asignaciones' : str,
'Tipo Unidad monetaria' : str,
'remuneracionbruta_mensual' : float,
'remuliquida_mensual' : float,
'Pago extra diurnas' : str,
'Horas extra diurnas' : str,
'Pago extra nocturnas' : str,
'Horas extra nocturnas' : str,
'Pago extra festivas' : str,
'Horas extra festivas' : str,
'fecha_ingreso' : str,
'fecha_termino' : str,
'observaciones' : str,
'enlace' : str,
'viaticos' : str}

path_codigotrabajo = 'data publica/PersonalCodigotrabajo.csv'
path_contrata = 'data publica/PersonalContrata.csv'
path_contratohonorarios = 'data publica/PersonalContratohonorarios.csv'
path_planta = 'data publica/PersonalPlanta.csv'

#Read
df_codigotrabajo = dd.read_csv(path_codigotrabajo, encoding='ISO-8859-1', delimiter=';', dtype = types)
df_contrata = dd.read_csv(path_contrata, encoding='ISO-8859-1', delimiter=';', dtype = types2)
df_honorarios = dd.read_csv(path_contratohonorarios, encoding='ISO-8859-1', delimiter=';', dtype = types)
df_planta = dd.read_csv(path_planta, encoding='ISO-8859-1', delimiter=';', dtype = types)

# %%
df_codigotrabajo.head()
# Out:
#             camino                                   organismo_nombre  \
# 0  /Año 2017/Enero                            Municipalidad de Vicuña
# 1  /Año 2017/Enero                            Municipalidad de Vicuña
# 2  /Año 2018/Abril  Asociación de Municipalidades Territorio de Ri...
# 3    /2018/Febrero  Ex Consejo Nacional de la Cultura y las Artes ...
# 4    /2018/Febrero  Ex Consejo Nacional de la Cultura y las Artes ...
#
#   organismo_codigo fecha_publicacion  anyo    Mes               Nombres  \
# 0            MU335        2017/03/09  2017  Enero                 César
# 1            MU335        2017/03/09  2017  Enero               Nicolás
# 2            MA011        2021/08/11  2018  Abril            Gina Maria
# 3            AV001        2018/05/15  2018  Enero  ELIZABETH DEL CARMEN
# 4            AV001        2018/05/15  2018  Enero               CLAUDIO
#
#     Paterno    Materno            Tipo cargo  ... Pago extra nocturnas  \
# ...

# %%
df_contrata.head()
# Out:
#       camino    organismo_nombre organismo_codigo fecha_publicacion  anyo  \
# 0  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 1  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 2  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 3  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 4  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
#
#      Mes  Tipo Estamento           Nombres   Paterno  Materno  ...  \
# 0   Mayo  Administrativo  CRISTIAN ESTEBAN    AVILEZ  STUARDO  ...
# 1  Marzo     Profesional       IVAN ANDRES   SALINAS  BALAGNA  ...
# 2  Marzo        Auxiliar    SERGIO ANTONIO  SAAVEDRA  VILCHES  ...
# 3  Marzo     Profesional     TAMARA ISABEL     RUBIO    THAMM  ...
# 4  Marzo        Auxiliar      KARYN LORENA     REYES    VIDAL  ...
#
#   Pago extra nocturnas Horas extra nocturnas Pago extra festivas  \
# ...

# %%
df_honorarios.head()
# Out:
#              camino                                   organismo_nombre  \
# 0    /Año 2017/Mayo  Asociación de Municipalidades del Valle del Maipo
# 1   /Año 2017/Junio  Asociación de Municipalidades del Valle del Maipo
# 2   /Año 2017/Julio  Asociación de Municipalidades del Valle del Maipo
# 3  /Año 2017/Agosto  Asociación de Municipalidades del Valle del Maipo
# 4   /2017/Noviembre  Asociación Municipalidades Provincia de Llanqu...
#
#   organismo_codigo fecha_publicacion  anyo        Mes           Nombres  \
# 0            MA049        2021/09/04  2017      Junio              Luis
# 1            MA049        2021/09/04  2017      Junio              Luis
# 2            MA049        2021/09/04  2017      Junio              Luis
# 3            MA049        2021/09/04  2017      Junio              Luis
# 4            MA025        2017/12/21  2017  Noviembre  Alejandro Javier
#
#     Paterno    Materno             grado_eus  ... Tipo Unidad monetaria  \
# ...

# %%
df_planta.head()
# Out:
#                                      camino             organismo_nombre  \
# 0  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 1  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 2  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 3  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 4  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
#
#   organismo_codigo fecha_publicacion  anyo    Mes  Tipo Estamento  \
# 0            MU229        2015/02/27  2014  Julio  Administrativo
# 1            MU229        2015/02/27  2014  Julio        Auxiliar
# 2            MU229        2015/02/27  2014  Julio         Técnico
# 3            MU229        2015/02/27  2014  Julio  Administrativo
# 4            MU229        2015/02/27  2014  Julio         Técnico
#
#             Nombres      Paterno      Materno  ... Pago extra nocturnas  \
# ...

# %%
dfs = {df_codigotrabajo : 'Codigotrabajo',
        df_contrata : 'Contrata',
        df_honorarios : 'Honorarios',
        df_planta : 'Planta'}

Anyo = 2020

Meses = {'Abril',
         'Agosto',
         'Diciembre',
         'Enero',
         'Febrero',
         'Julio',
         'Junio',
         'Marzo',
         'Mayo',
         'Noviembre',
         'Octubre',
         'Septiembre'}


aux = {}

for df in dfs:
    
    currentYear = df[df.anyo == str(Anyo)]
    mes = 'Febrero'
    month =  currentYear[currentYear.Mes == mes]
    aux[dfs[df]] = month
    month.to_csv('data publica/por contrato/' + mes + str(Anyo) + dfs[df] +'.csv', single_file = True)

    #for mes in Meses:
    #    month =  currentYear[currentYear.Mes == mes]
    #    month.to_csv('data publica/por mes/' + mes + str(Anyo) + dfs[df] +'.csv', single_file = True)

# %%
target = 0
for a in aux:
    lenght = len(aux[a].index)
    print(a + ' : ' + str(lenght))
    target += lenght
print('lenght: ', target)
# Out:
# Codigotrabajo : 111184
# Contrata : 310300
# Honorarios : 91390
# Planta : 162111
# lenght:  674985

# %%
df_whole = dd.concat(list(aux.values()))
len(df_whole.index)
# Out:
# 674985

# %%
df_whole.to_csv('data publica/unidos/' + mes + str(Anyo) + '.csv', single_file = True)
# Out:
# ['/Users/nicolasvega/Desktop/Personal/transparency-project/paper/data publica/unidos/Febrero2020.csv']
