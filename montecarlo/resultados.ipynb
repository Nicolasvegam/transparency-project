# %% [markdown]
# # #0

# %%
# ---- ¿Que año, mes y # de iteraciones quieres correr? ----
anyo = '2020'
mes = 'Abril'
iters = 10

# %%
# ---- Librerías ---- 
import pandas as pd 
import numpy as np
import csv 
import warnings
warnings.filterwarnings('ignore')

# %%
# ---- Método MonteCarlo ---- 
def MonteCarlo(population, sample_number, weights_column, 
                        current_distint_names, iterations):
    
    sum_distint_names = 0 #numero de apellidos distintos
    higher = 0       #veces que el # de apellidos simulado fue mayor al actual
    lower = 0        #veces que el # de apellidos simulado fue menor al actual
    equal = 0        #veces que el # de apellidos simulado fue igual al actual
    
    
    for i in range(0, iterations): #numero de iteraciones
        
        #esto saca un random example de la poblacion (general), le damos un "N" y un peso específico a cada apellido
        random_weighted_sample = population.sample(n = sample_number, replace = True, 
                                                   weights= weights_column, axis = 0)
        
        #sacamos el numero de apellidos distintos simulados
        distint_names = len(set(random_weighted_sample.index)) #Assuming index contains surnames
        
        
        sum_distint_names += distint_names
        
        
        if distint_names > current_distint_names:
            
            higher += 1

        elif distint_names < current_distint_names:
            
            lower += 1
        
        else:
            
            equal += 1
         
    #guardar output
    output = {'Employees': sample_number,
              'AVG Surnames': sum_distint_names/iterations, 
              'Current Surnames': current_distint_names, 
              '# Simulated > Current': higher, 
              '# Simulated < Current': lower, 
              '# Simulated = Current': equal, 
              'Iterations': iterations
             }
    
    return output

# %%
# ---- DB Apellidos Paternos ---- 
df_paternos = pd.read_excel('data publica/apellidos_paternos.xlsx', index_col=0, usecols = 'A:D',engine="openpyxl")

# %%
# ---- DB Instituciones ---- 
df_instituciones = pd.read_csv('data publica/Acronimos Organismos.csv', index_col=0, encoding="ISO-8859-1", delimiter =';')

# %%
# ---- DB Employees ---- 
df_whole = pd.read_csv('data publica/unidos/'+ mes + anyo + '.csv', index_col=0)

# %%
## ---------- Remover tildes de los apellidos y pasar a mayuscula ---------- ##
cols = df_paternos.select_dtypes(include=[np.object]).columns
df_paternos[cols] =df_paternos[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
cols = df_whole.select_dtypes(include=[np.object]).columns
df_whole[cols] =df_whole[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
df_whole['Paterno'] = df_whole['Paterno'].str.upper()
df_whole['Materno'] = df_whole['Materno'].str.upper()

# %%
## ---------- Apellidos Paternos x Región ---------- ##
pd.options.display.float_format = '{:,.2f}'.format 
df_paternos['AP PATERNO'] = df_paternos['AP PATERNO'].str.upper()
df_paternos_region = df_paternos[df_paternos['AP PATERNO'].notna()]
df_paternos_region = df_paternos_region.groupby(['REG','AP PATERNO']).agg({'CANTIDAD': "sum"}).sort_values(by=['CANTIDAD'], ascending=False)
df_paternos_region = df_paternos_region[df_paternos_region['CANTIDAD'] > 1]
df_paternos_region['CANTIDAD'] = df_paternos_region['CANTIDAD'].astype(int)
## ---------- Apellidos Paternos en Chile ---------- ##
df_paternos_region = df_paternos_region.reset_index(level=['REG'])
df_paternos_total = df_paternos_region.groupby(['AP PATERNO']).agg({'CANTIDAD': "sum"}).sort_values(by=['CANTIDAD'], ascending=False)
df_paternos_total['PORCENTAJE'] = (df_paternos_total['CANTIDAD']/df_paternos_total['CANTIDAD'].sum())
df_paternos_total['CANTIDAD'] = df_paternos_total['CANTIDAD'].astype(int)
df_paternos_total = df_paternos_total.dropna()
df_paternos_total = df_paternos_total[df_paternos_total['CANTIDAD'] > 1]

# %%
df_paternos_total

# %%
region_codes = {'Region Metropolitana de Santiago':13,
                'Region de Antofagasta':2,
                'Region de Arica y Parinacota':15,
                'Region de Atacama':3,
                'Region de Aysen':11,
                'Region de Coquimbo':4,
                'Region de La Araucania':9,
                'Region de Los Lagos':10,
                'Region de Los Rios':14,
                'Region de Magallanes':12,
                'Region de Nuble':16,
                'Region de OHiggins':6,
                'Region de Tarapaca':1,
                'Region de Valparaiso':5,
                'Region del Biobio':8,
                'Region del Maule':7}

# %% [markdown]
# # #1

# %%
#numero de apellidos unicos en el organismo
distint_names_organismo = len(set(df_whole['Paterno'].value_counts().index)) 

#numero de personas en el organismo
total = len(df_whole['Paterno'])

#saca todos los apellidos de la región
population = df_paternos_total

#El peso de los apellidos de la región
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

#Ejecutar MonteCarlo
output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_organismo, iters)

# %%
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-61353e8b2d5a> in <module>
# ----> 1 output
#
# NameError: name 'output' is not defined

# %% [markdown]
# # #2

# %%
df_merged = pd.merge(df_whole, df_instituciones, left_on='organismo_codigo', right_on='Codigo_org', how='inner')
areas = set(df_merged['Padre_org'].value_counts().index)

# %%
dict_regiones = { 'Defensa Nacional' : 'All' ,
'Vivienda y Urbanismo' : 'All' ,
'Municipios de Tarapacá' : 'Region de Tarapaca' ,
'Municipios de Atacama' : 'Region de Atacama' ,
'Minería' : 'All' ,
'Medio Ambiente' : 'All' ,
'Educación' : 'All' ,
'Transportes y Telecomunicaciones' : 'All' ,
'Asociación Municipal' : 'All' ,
'Salud' : 'All' ,
'Agricultura' : 'All' ,
'Municipios de Los Lagos' : 'Region de Los Lagos' ,
'La Mujer y Equidad de Género' : 'All' ,
'Municipios de R. Metropolitana de Santiago' : 'Region Metropolitana de Santiago' ,
'Deporte' : 'All' ,
'Secretaría General de Gobierno' : 'All' ,
'Centro de Formación Técnica' : 'All' ,
'Bienes Nacionales' : 'All' ,
'Secretaría General de la Presidencia' : 'All' ,
'Universidades' : 'All' ,
'Municipios del Libertador General Bernardo OHiggins' : 'Region de OHiggins' ,
'Interior y Seguridad Pública' : 'All' ,
'Municipios de Aysen del General Carlos Ibáñez del Campo' : 'Region de Aysen' ,
'Defensoría de los Derechos de la Niñez' : 'All' ,
'Energía' : 'All' ,
'Municipios de Antofagasta' : 'Region de Antofagasta' ,
'Justicia' : 'All' ,
'Municipios del Bíobio' : 'Region del Biobio' ,
'Corporaciones Municipales' : 'All' ,
'Municipios de La Araucanía' : 'Region de La Araucania' ,
'Municipios de Valparaíso' : 'All' ,
'Consejo Defensa del Estado' : 'All' ,
'Municipios de Ñuble' : 'All' ,
'Municipios de Arica y  Parinacota' : 'Region de Arica y Parinacota' ,
'Superintendencia de Servicios Sanitarios' : 'All' ,
'Municipios de Magallanes y de la Antártica Chilena' : 'Region de Magallanes' ,
'Economía Fomento y Turismo' : 'All' ,
'Municipios del Maule' : 'Region del Maule' ,
'Desarrollo Social' : 'All' ,
'Presidencia de la República' : 'All' ,
'Municipios de Los Ríos' : 'Region de Los Rios' ,
'Trabajo y Previsión Social' : 'All' ,
'Fundaciones y corporaciones' : 'All' ,
'Culturas y las Artes' : 'All' ,
'Hacienda' : 'All' ,
'Municipios de Coquimbo' : 'Region de Coquimbo' ,
'Instituto Derechos Humanos' : 'All' ,
'Obras Públicas' : 'All' ,
'Ciencia Tecnología e Innovación' : 'All' ,
'Consejo para la Transparencia' : 'All' ,
'Relaciones Exteriores' : 'All'
}

# %%
dict_areas = {}

for area in areas:
    
    #Se filtra la planta por area
    df_area = df_merged[df_merged['Padre_org'] == area]    

    #Número de personas en el área
    totalOrg = len(df_area['Paterno'])
    
    #Si el área tiene más de cien personas
    if totalOrg > 30 :
        
        #Top 10%
        distint_names_area = len(set(df_area['Paterno'].value_counts().index))
        total = len(df_area['Paterno'])    
        region = df_area['region']
        regiones = set(region)
        lenght = len(regiones)
        regiones = list(val for val in regiones)

        if lenght == 1:
            region = regiones[0]
            region = unicodedata.normalize("NFKD",region).encode("ascii","ignore").decode("ascii")
            code_region = region_codes[region]  
            population = df_paternos_region[df_paternos_region['REG'] == code_region] 
        
        #Composición toda la poblacion
        else:
            import unicodedata
            population = df_paternos_total

        population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
        output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_area, iters)
        
        dict_areas[area] = output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5c74bf6ef9e5> in <module>
#      29         else:
#      30             import unicodedata
# ---> 31             population = df_paternos_total
#      32
#      33         population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
#
# NameError: name 'df_paternos_total' is not defined

# %%
dict_areas
# Out:
# {'Defensa Nacional': {'Employees': 15161,
#   'AVG Surnames': 2686.98705,
#   'Current Surnames': 2821,
#   '# Simulated > Current': 8,
#   '# Simulated < Current': 99991,
#   '# Simulated = Current': 1,
#   'Iterations': 100000},
#  'Vivienda y Urbanismo': {'Employees': 6298,
#   'AVG Surnames': 1577.82768,
#   'Current Surnames': 1663,
#   '# Simulated > Current': 61,
#   '# Simulated < Current': 99933,
#   '# Simulated = Current': 6,
#   'Iterations': 100000},
#  'Municipios de Tarapacá': {'Employees': 1870,
#   'AVG Surnames': 789.48575,
#   'Current Surnames': 674,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Atacama': {'Employees': 4033,
#   'AVG Surnames': 892.51955,
#   'Current Surnames': 884,
#   '# Simulated > Current': 67923,
#   '# Simulated < Current': 30073,
#   '# Simulated = Current': 2004,
#   'Iterations': 100000},
#  'Minería': {'Employees': 914,
#   'AVG Surnames': 481.85162,
#   'Current Surnames': 522,
#   '# Simulated > Current': 52,
#   '# Simulated < Current': 99933,
#   '# Simulated = Current': 15,
#   'Iterations': 100000},
#  'Medio Ambiente': {'Employees': 1266,
#   'AVG Surnames': 595.10165,
#   'Current Surnames': 635,
#   '# Simulated > Current': 271,
#   '# Simulated < Current': 99670,
#   '# Simulated = Current': 59,
#   'Iterations': 100000},
#  'Educación': {'Employees': 46951,
#   'AVG Surnames': 5393.46346,
#   'Current Surnames': 4745,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Transportes y Telecomunicaciones': {'Employees': 2082,
#   'AVG Surnames': 811.35636,
#   'Current Surnames': 840,
#   '# Simulated > Current': 4747,
#   '# Simulated < Current': 94644,
#   '# Simulated = Current': 609,
#   'Iterations': 100000},
#  'Asociación Municipal': {'Employees': 448,
#   'AVG Surnames': 294.06514,
#   'Current Surnames': 290,
#   '# Simulated > Current': 65627,
#   '# Simulated < Current': 30290,
#   '# Simulated = Current': 4083,
#   'Iterations': 100000},
#  'Salud': {'Employees': 199403,
#   'AVG Surnames': 12629.24211,
#   'Current Surnames': 12529,
#   '# Simulated > Current': 91529,
#   '# Simulated < Current': 8277,
#   '# Simulated = Current': 194,
#   'Iterations': 100000},
#  'Agricultura': {'Employees': 7288,
#   'AVG Surnames': 1722.51232,
#   'Current Surnames': 1784,
#   '# Simulated > Current': 1219,
#   '# Simulated < Current': 98663,
#   '# Simulated = Current': 118,
#   'Iterations': 100000},
#  'Municipios de Los Lagos': {'Employees': 24601,
#   'AVG Surnames': 2893.33966,
#   'Current Surnames': 2583,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'La Mujer y Equidad de Género': {'Employees': 624,
#   'AVG Surnames': 372.17823,
#   'Current Surnames': 407,
#   '# Simulated > Current': 33,
#   '# Simulated < Current': 99951,
#   '# Simulated = Current': 16,
#   'Iterations': 100000},
#  'Municipios de R. Metropolitana de Santiago': {'Employees': 56459,
#   'AVG Surnames': 6724.60285,
#   'Current Surnames': 5225,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Deporte': {'Employees': 3838,
#   'AVG Surnames': 1173.41042,
#   'Current Surnames': 1135,
#   '# Simulated > Current': 96076,
#   '# Simulated < Current': 3560,
#   '# Simulated = Current': 364,
#   'Iterations': 100000},
#  'Secretaría General de Gobierno': {'Employees': 778,
#   'AVG Surnames': 432.7718,
#   'Current Surnames': 465,
#   '# Simulated > Current': 247,
#   '# Simulated < Current': 99669,
#   '# Simulated = Current': 84,
#   'Iterations': 100000},
#  'Centro de Formación Técnica': {'Employees': 359,
#   'AVG Surnames': 249.65432,
#   'Current Surnames': 244,
#   '# Simulated > Current': 74418,
#   '# Simulated < Current': 21613,
#   '# Simulated = Current': 3969,
#   'Iterations': 100000},
#  'Bienes Nacionales': {'Employees': 762,
#   'AVG Surnames': 426.85392,
#   'Current Surnames': 441,
#   '# Simulated > Current': 10349,
#   '# Simulated < Current': 88052,
#   '# Simulated = Current': 1599,
#   'Iterations': 100000},
#  'Secretaría General de la Presidencia': {'Employees': 349,
#   'AVG Surnames': 244.37056,
#   'Current Surnames': 263,
#   '# Simulated > Current': 657,
#   '# Simulated < Current': 99050,
#   '# Simulated = Current': 293,
#   'Iterations': 100000},
#  'Universidades': {'Employees': 944,
#   'AVG Surnames': 492.25618,
#   'Current Surnames': 494,
#   '# Simulated > Current': 42861,
#   '# Simulated < Current': 53957,
#   '# Simulated = Current': 3182,
#   'Iterations': 100000},
#  'Municipios del Libertador General Bernardo OHiggins': {'Employees': 18772,
#   'AVG Surnames': 1534.95501,
#   'Current Surnames': 1772,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Interior y Seguridad Pública': {'Employees': 4599,
#   'AVG Surnames': 1307.32811,
#   'Current Surnames': 1434,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Aysen del General Carlos Ibáñez del Campo': {'Employees': 4530,
#   'AVG Surnames': 964.43604,
#   'Current Surnames': 1101,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Defensoría de los Derechos de la Niñez': {'Employees': 51,
#   'AVG Surnames': 47.38795,
#   'Current Surnames': 47,
#   '# Simulated > Current': 50738,
#   '# Simulated < Current': 29552,
#   '# Simulated = Current': 19710,
#   'Iterations': 100000},
#  'Energía': {'Employees': 1474,
#   'AVG Surnames': 655.19735,
#   'Current Surnames': 619,
#   '# Simulated > Current': 99095,
#   '# Simulated < Current': 743,
#   '# Simulated = Current': 162,
#   'Iterations': 100000},
#  'Municipios de Antofagasta': {'Employees': 2914,
#   'AVG Surnames': 925.25374,
#   'Current Surnames': 788,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Justicia': {'Employees': 12977,
#   'AVG Surnames': 2442.92233,
#   'Current Surnames': 2444,
#   '# Simulated > Current': 48164,
#   '# Simulated < Current': 50662,
#   '# Simulated = Current': 1174,
#   'Iterations': 100000},
#  'Municipios del Bíobio': {'Employees': 36081,
#   'AVG Surnames': 2559.37686,
#   'Current Surnames': 2677,
#   '# Simulated > Current': 16,
#   '# Simulated < Current': 99983,
#   '# Simulated = Current': 1,
#   'Iterations': 100000},
#  'Corporaciones Municipales': {'Employees': 63973,
#   'AVG Surnames': 6514.69184,
#   'Current Surnames': 6086,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de La Araucanía': {'Employees': 20805,
#   'AVG Surnames': 2748.14146,
#   'Current Surnames': 2534,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Valparaíso': {'Employees': 25183,
#   'AVG Surnames': 3672.70568,
#   'Current Surnames': 2787,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Consejo Defensa del Estado': {'Employees': 633,
#   'AVG Surnames': 375.8905,
#   'Current Surnames': 387,
#   '# Simulated > Current': 13696,
#   '# Simulated < Current': 84138,
#   '# Simulated = Current': 2166,
#   'Iterations': 100000},
#  'Municipios de Ñuble': {'Employees': 17162,
#   'AVG Surnames': 2899.23967,
#   'Current Surnames': 1832,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Arica y  Parinacota': {'Employees': 298,
#   'AVG Surnames': 211.52772,
#   'Current Surnames': 168,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Superintendencia de Servicios Sanitarios': {'Employees': 204,
#   'AVG Surnames': 160.26714,
#   'Current Surnames': 155,
#   '# Simulated > Current': 80556,
#   '# Simulated < Current': 14892,
#   '# Simulated = Current': 4552,
#   'Iterations': 100000},
#  'Municipios de Magallanes y de la Antártica Chilena': {'Employees': 1531,
#   'AVG Surnames': 588.48073,
#   'Current Surnames': 555,
#   '# Simulated > Current': 98573,
#   '# Simulated < Current': 1208,
#   '# Simulated = Current': 219,
#   'Iterations': 100000},
#  'Economía Fomento y Turismo': {'Employees': 7051,
#   'AVG Surnames': 1688.44274,
#   'Current Surnames': 1925,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios del Maule': {'Employees': 32689,
#   'AVG Surnames': 1779.29961,
#   'Current Surnames': 2113,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Desarrollo Social': {'Employees': 3626,
#   'AVG Surnames': 1134.02938,
#   'Current Surnames': 1328,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Presidencia de la República': {'Employees': 468,
#   'AVG Surnames': 303.54507,
#   'Current Surnames': 319,
#   '# Simulated > Current': 4003,
#   '# Simulated < Current': 94954,
#   '# Simulated = Current': 1043,
#   'Iterations': 100000},
#  'Municipios de Los Ríos': {'Employees': 8163,
#   'AVG Surnames': 1377.57106,
#   'Current Surnames': 1368,
#   '# Simulated > Current': 68557,
#   '# Simulated < Current': 29562,
#   '# Simulated = Current': 1881,
#   'Iterations': 100000},
#  'Trabajo y Previsión Social': {'Employees': 8062,
#   'AVG Surnames': 1830.19731,
#   'Current Surnames': 1843,
#   '# Simulated > Current': 31910,
#   '# Simulated < Current': 66789,
#   '# Simulated = Current': 1301,
#   'Iterations': 100000},
#  'Fundaciones y corporaciones': {'Employees': 272,
#   'AVG Surnames': 201.69011,
#   'Current Surnames': 193,
#   '# Simulated > Current': 88941,
#   '# Simulated < Current': 8515,
#   '# Simulated = Current': 2544,
#   'Iterations': 100000},
#  'Culturas y las Artes': {'Employees': 3247,
#   'AVG Surnames': 1061.36073,
#   'Current Surnames': 1203,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Hacienda': {'Employees': 5937,
#   'AVG Surnames': 1523.02241,
#   'Current Surnames': 1588,
#   '# Simulated > Current': 540,
#   '# Simulated < Current': 99395,
#   '# Simulated = Current': 65,
#   'Iterations': 100000},
#  'Municipios de Coquimbo': {'Employees': 16155,
#   'AVG Surnames': 1438.40885,
#   'Current Surnames': 1596,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Instituto Derechos Humanos': {'Employees': 194,
#   'AVG Surnames': 153.81608,
#   'Current Surnames': 156,
#   '# Simulated > Current': 31039,
#   '# Simulated < Current': 61920,
#   '# Simulated = Current': 7041,
#   'Iterations': 100000},
#  'Obras Públicas': {'Employees': 9123,
#   'AVG Surnames': 1972.1143,
#   'Current Surnames': 1898,
#   '# Simulated > Current': 99337,
#   '# Simulated < Current': 611,
#   '# Simulated = Current': 52,
#   'Iterations': 100000},
#  'Ciencia Tecnología e Innovación': {'Employees': 116,
#   'AVG Surnames': 99.53828,
#   'Current Surnames': 103,
#   '# Simulated > Current': 13938,
#   '# Simulated < Current': 78705,
#   '# Simulated = Current': 7357,
#   'Iterations': 100000},
#  'Consejo para la Transparencia': {'Employees': 161,
#   'AVG Surnames': 131.78205,
#   'Current Surnames': 134,
#   '# Simulated > Current': 28540,
#   '# Simulated < Current': 63697,
#   '# Simulated = Current': 7763,
#   'Iterations': 100000},
#  'Relaciones Exteriores': {'Employees': 280,
#   'AVG Surnames': 206.34827,
#   'Current Surnames': 221,
#   '# Simulated > Current': 1225,
#   '# Simulated < Current': 98213,
#   '# Simulated = Current': 562,
#   'Iterations': 100000}}

# %%
nombre_archivo = 'resultados/3-{0}.csv'.format(iters)
data = [] 
columns = []

for key, value in dict_areas.items():
    data.append(value)
    columns.append(key)
    
total = pd.DataFrame(data, index = columns) 
total.to_csv(nombre_archivo)

# %% [markdown]
# # #3

# %%
df_planta = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Planta.csv', index_col=0)
df_honorarios = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Honorarios.csv', index_col=0)
df_contrata = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Contrata.csv', index_col=0)
df_codigotrabajo = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Codigotrabajo.csv', index_col=0)

# %%
surnames_planta = len(set(df_planta['Paterno'].value_counts().index))
total_planta = len(df_planta['Paterno'])
surnames_contrata = len(set(df_contrata['Paterno'].value_counts().index))
total_contrata = len(df_contrata['Paterno'])
surnames_honorarios = len(set(df_honorarios['Paterno'].value_counts().index))
total_honorarios = len(df_honorarios['Paterno'])
surnames_codigotrabajo = len(set(df_codigotrabajo['Paterno'].value_counts().index))
total_codigotrabajo = len(df_codigotrabajo['Paterno'])
population = df_paternos_total
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

output_planta = MonteCarlo(population, total_planta, 'PORCENTAJE', surnames_planta, iters)
output_contrata = MonteCarlo(population, total_contrata, 'PORCENTAJE', surnames_contrata, iters)
output_honorarios = MonteCarlo(population, total_honorarios, 'PORCENTAJE', surnames_honorarios, iters)
output_codigotrabajo = MonteCarlo(population, total_codigotrabajo, 'PORCENTAJE', surnames_codigotrabajo, iters)

# %%
output_planta, output_contrata, output_honorarios, output_codigotrabajo
# Out:
# ({'Employees': 162505,
#   'AVG Surnames': 11269.26061,
#   'Current Surnames': 12326,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 298139,
#   'AVG Surnames': 15657.99061,
#   'Current Surnames': 19512,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 109785,
#   'AVG Surnames': 8993.98358,
#   'Current Surnames': 12302,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 110775,
#   'AVG Surnames': 9041.67073,
#   'Current Surnames': 10136,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000})

# %% [markdown]
# # #4

# %%
#Dictionario con los resultados
dict_regiones = {}

#Para cada organismo
for region in region_codes:
    
    df_region = df[df['region'] == region]

    #numero de apellidos unicos en el organismo
    distint_names_region = len(set(df_region['Paterno'].value_counts().index))

    #numero de personas en el organismo
    total = len(df_region['Paterno'])
        
    import unicodedata
    region = unicodedata.normalize("NFKD",region).encode("ascii","ignore").decode("ascii")

    #codigo de la región
    code_region = region_codes[region]  
    
    #saca todos los apellidos de la región
    population = df_paternos_region[df_paternos_region['REG'] == code_region]
    
    #El peso de los apellidos de la región
    population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
    
    #Ejecutar MonteCarlo
    output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_region, iters)
    
    #Guardar resultado
    dict_regiones[region] = output

# %%
dict_regiones
# Out:
# {'Region Metropolitana de Santiago': {'Employees': 220135,
#   'AVG Surnames': 15123.49602,
#   'Current Surnames': 13537,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Antofagasta': {'Employees': 22753,
#   'AVG Surnames': 2691.58451,
#   'Current Surnames': 2841,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Arica y Parinacota': {'Employees': 9885,
#   'AVG Surnames': 1571.34047,
#   'Current Surnames': 1875,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Atacama': {'Employees': 13361,
#   'AVG Surnames': 1529.29652,
#   'Current Surnames': 1711,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Aysen': {'Employees': 11405,
#   'AVG Surnames': 1413.79023,
#   'Current Surnames': 1889,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Coquimbo': {'Employees': 32685,
#   'AVG Surnames': 1966.11664,
#   'Current Surnames': 2608,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de La Araucania': {'Employees': 41960,
#   'AVG Surnames': 3698.93105,
#   'Current Surnames': 3922,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Los Lagos': {'Employees': 46666,
#   'AVG Surnames': 3851.65931,
#   'Current Surnames': 4032,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Los Rios': {'Employees': 17301,
#   'AVG Surnames': 1801.08911,
#   'Current Surnames': 2435,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Magallanes': {'Employees': 8051,
#   'AVG Surnames': 1586.63134,
#   'Current Surnames': 1661,
#   '# Simulated > Current': 75,
#   '# Simulated < Current': 99913,
#   '# Simulated = Current': 12,
#   'Iterations': 100000},
#  'Region de Nuble': {'Employees': 24952,
#   'AVG Surnames': 188.0,
#   'Current Surnames': 2271,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de OHiggins': {'Employees': 37026,
#   'AVG Surnames': 2075.90602,
#   'Current Surnames': 2891,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Tarapaca': {'Employees': 9679,
#   'AVG Surnames': 1992.19195,
#   'Current Surnames': 2068,
#   '# Simulated > Current': 215,
#   '# Simulated < Current': 99755,
#   '# Simulated = Current': 30,
#   'Iterations': 100000},
#  'Region de Valparaiso': {'Employees': 64556,
#   'AVG Surnames': 5052.11416,
#   'Current Surnames': 5567,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region del Biobio': {'Employees': 72123,
#   'AVG Surnames': 3602.81768,
#   'Current Surnames': 4225,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region del Maule': {'Employees': 48666,
#   'AVG Surnames': 2115.30051,
#   'Current Surnames': 2849,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000}}

# %%
nombre_archivo = 'resultados/4-{0}.csv'.format(numero_iteraciones)
data = [] 
columns = []

for key, value in dict_regiones.items():
    data.append(value)
    columns.append(key)
    
total = pd.DataFrame(data, index = columns) 
total.to_csv(nombre_archivo)

# %% [markdown]
# # #5

# %%
#Dictionario con los resultados
dict_organismos = {}

#Generar deciles en base a la remuneración bruta
df_whole['decilePlanta'] = pd.qcut(df_whole['remuneracionbruta_mensual'], 10, labels=False, duplicates='drop')
    
#Total de empleados en ese organismo
totalAll = len(df_whole['Paterno'])
    
#Decil Top
topDecil = df_whole[df_whole['decilePlanta'] == 9]
    
#Decil bottom
bottomDecil = df_whole[df_whole['decilePlanta'] == 0]
    
#---------------------------Para el top 10% --------------------------#
        
#Cantidad única de apellidos
distint_names_organismo = len(set(topDecil['Paterno'].value_counts().index))
        
#Cantidad de personas en el decil top
totalTop = len(topDecil['Paterno'])
        
#Población de esa región
population = df_paternos_total 
        
#Sacamos los pesos de cada apellido i.e, el porcentaje en esa región
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
        
#Corremos la Monte Carlo
outputTop = MonteCarlo(population, totalTop, 'PORCENTAJE', distint_names_organismo, iters)
        
#---------------------------Para el bottom 10% --------------------------#

#Para el bottom 90%
distint_names_organismo = len(set(bottomDecil['Paterno'].value_counts().index))
        
totalBottom = len(bottomDecil['Paterno'])
                
outputBottom = MonteCarlo(population, totalBottom, 'PORCENTAJE', distint_names_organismo, iters)

# %%
outputTop, outputBottom
# Out:
# ({'Employees': 57141,
#   'AVG Surnames': 6082.49902,
#   'Current Surnames': 8006,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 57142,
#   'AVG Surnames': 6082.61031,
#   'Current Surnames': 4946,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000})

# %%
#Generar deciles en base a la remuneración bruta
dict_deciles = {}
df_whole['decilePlanta'] = pd.qcut(df_whole['remuneracionbruta_mensual'], 10, labels=False, duplicates='drop')
    
#Población
population = df_paternos_total 
        
#Sacamos los pesos de cada apellido i.e, el porcentaje en esa región
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

for i in range (0, 10):
    
    Decil = df[df['decilePlanta'] == i]
    
    #Apellidos unicos en el decil
    distint_names_decil = len(set(Decil['Paterno'].value_counts().index))
        
    #Cantidad de personas en el decil top
    totalDecil = len(Decil['Paterno'])
        
    #Corremos la Monte Carlo
    output = MonteCarlo(population, totalDecil, 'PORCENTAJE', distint_names_decil, iters)
        
    dict_deciles[i] = output

# %%
dict_deciles
# Out:
# {0: {'Employees': 57142,
#   'AVG Surnames': 6082.34517,
#   'Current Surnames': 4946,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  1: {'Employees': 57260,
#   'AVG Surnames': 6089.96622,
#   'Current Surnames': 4833,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  2: {'Employees': 57026,
#   'AVG Surnames': 6074.60493,
#   'Current Surnames': 4934,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  3: {'Employees': 57140,
#   'AVG Surnames': 6082.21288,
#   'Current Surnames': 5158,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  4: {'Employees': 57142,
#   'AVG Surnames': 6082.56726,
#   'Current Surnames': 5392,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  5: {'Employees': 57141,
#   'AVG Surnames': 6082.35053,
#   'Current Surnames': 5623,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  6: {'Employees': 57142,
#   'AVG Surnames': 6082.6081,
#   'Current Surnames': 5859,
#   '# Simulated > Current': 99998,
#   '# Simulated < Current': 2,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  7: {'Employees': 57144,
#   'AVG Surnames': 6082.64401,
#   'Current Surnames': 6210,
#   '# Simulated > Current': 910,
#   '# Simulated < Current': 99048,
#   '# Simulated = Current': 42,
#   'Iterations': 100000},
#  8: {'Employees': 57141,
#   'AVG Surnames': 6082.60894,
#   'Current Surnames': 7118,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  9: {'Employees': 57141,
#   'AVG Surnames': 6082.0922,
#   'Current Surnames': 8006,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000}}

# %%
df_whole['decilePlanta'] = pd.qcut(df_whole['remuneracionbruta_mensual'], 10, labels=False, duplicates='drop')

# %%
for i in range(0, 10):
    print(df_whole[df_whole['decilePlanta'] == i]['remuneracionbruta_mensual'].mean())
# Out:
# 266992.2489937349
# 508766.4577541041
# 619183.8664819556
# 765526.9605180259
# 946344.4143012145
# 1141336.9859295427
# 1381296.6142767142
# 1717019.5933256336
# 2190539.5756462086
# 3486188.8169440506

# %%
## Co-ocurrencia de apellidos:
# ---- DB Employees ---- 
freq = df_whole.groupby(["Paterno", "Materno"]).size()
freq
# Out:
# Paterno    Materno
# .          .             1
# AABY       HORMAZABAL    1
#            RIOS          1
# AAZCO      FUENTES       1
# ABACA      BENAVIDES     1
#                         ..
# ZWETAJEFF  MARCHANT      1
# ZWINGEL    RIO           2
# ZYCER      GROSSMAN      1
# ZYL        GONZALEZ      1
#            TORRES        1
# Length: 296578, dtype: int64

# %%
def get_freq_names(series):
    names = {}
    all_names = list(series.index)
    length = len(series)

    for i in range(0,length):

        name = all_names[i]
        paternal = name[0]
        maternal = name[1]
        value = series[i]

        if (paternal, maternal) in names:
            name[(paternal, maternal)] = name[(paternal, maternal)] + value
        elif (maternal, paternal) in names:
            names[(maternal, paternal)] = names[(maternal, paternal)] + value    
        elif (paternal, maternal) not in names:
            if (maternal, paternal) not in names:
                names[(paternal, maternal)] = value  
    
    df = pd.DataFrame(names.items(), columns=['names', 'n'])
    return df


get_freq_names(freq)
# Out:
#                       names  n
# 0           (ABADIE, RIVAS)  2
# 1       (ABARCA, CONTRERAS)  1
# 2          (ABARCA, WALLIS)  1
# 3          (ABARZUA, LILLO)  1
# 4         (ABARZUA, RIVERA)  1
# ...                     ... ..
# 7985      (ZUNIGA, URRIETA)  1
# 7986  (ZUNIGA, VALDEBENITO)  2
# 7987       (ZUNIGA, VARGAS)  1
# 7988    (ZUNIGA, VELASQUEZ)  1
# 7989       (ZUNIGA, ZUNIGA)  3
#
# [7990 rows x 2 columns]

# %%
regions = set(df_whole.region)

for region in regions:
    df_region = df_whole[df_whole.region == region]
    freq = df_region.groupby(["Paterno", "Materno"]).size()
    df_names = get_freq_names(freq)
    df_names.to_csv('data publica/apellidos/' + region + '.csv')

# %%
metro = df_whole[df_whole.region == 'Region Metropolitana de Santiago']
g_p = metro[(metro.Paterno == 'GONZALEZ') & (metro.Materno == 'PEREZ')]
p_g = metro[(metro.Paterno == 'PEREZ') & (metro.Materno == 'GONZALEZ')]

# %%
g_p
# Out:
#                                                    camino  \
# 11499                               /Educacion/2020/Abril
# 96044                       /Area de Educacion/2020/Abril
# 92839   /2020/Comando General de Personal/Comando de S...
# 46014                           /Ano 2020/Educacion/Abril
# 205978                                        /2020/Abril
# 163166                              /Educacion/2020/Abril
# 92713                                         /2020/Abril
# 98051                                    /2020/Abril 2020
# 118280                                        /2020/Abril
# 118281                                        /2020/Abril
# 195072                                    /Ano 2020/Abril
# 13863   /Personal de Educacion a Contrata/Contrata Edu...
# 200054                                        /2020/Abril
# 142798                                    /Ano 2020/Abril
# 189115                                        /2020/Abril
# 13179                                         /2020/Abril
# 13180                                         /2020/Abril
# 87866                                     /Ano 2020/Abril
# 104577                              /Municipal 2020/Abril
# 8004                                          /2020/Abril
# 8005                                          /2020/Abril
# 103142                              /2020/Educacion/Abril
# 14372                           /Municipal/Ano 2020/Abril
# 10692                                         /2020/ABRIL
# 65358                     /Municipal/Municipal 2020/Abril
# 19585                                         /2020/Abril
# 19586                                         /2020/Abril
# 19587                                         /2020/Abril
# 130982                         /Administracion/2020/Abril
# 41497                                         /2020/Abril
# 67128                                         /2020/Abril
# 51521                                         /2020/Abril
# 151184                          /Municipal/Ano 2020/Abril
# 43655                                         /2020/Abril
# 84293                           /Area de Salud/2020/Abril
# 5438                                          /2020/Abril
# 32566                                         /2020/Abril
# 102167                                        /2020/Abril
# 150017                          /MUNICIPAL/Ano 2020/Abril
# 113281                                  /Salud/2020/Abril
# 12200           /Municipal/Historico 2016-2020/2020/Abril
# 145732                              /Salud/Ano 2020/Abril
#
#                                         organismo_nombre organismo_codigo  \
# 11499                 Corporacion Municipal de Melipilla            CM042
# 96044               Corporacion Municipal de Puente Alto            CM044
# 92839                                  Ejercito de Chile            AD006
# 46014                          Municipalidad de Santiago            MU308
# 205978  Servicio Local de Educacion Publica de Barrancas            AJ016
# 163166             Corporacion Municipal de San Bernardo            CM033
# 92713              Servicio Nacional de Menores (SENAME)            AK004
# 98051                          Hospital San Juan de Dios            AO075
# 118280                             Hospital Felix Bulnes            AO073
# 118281                             Hospital Felix Bulnes            AO073
# 195072                              Hospital Barros Luco            AO080
# 13863                         Municipalidad de Cerrillos            MU034
# 200054                                 Hospital San Jose            AO071
# 142798         Servicio Nacional del Patrimonio Cultural            BC003
# 189115                               Hospital Luis Tisne            AO106
# 13179      Junta Nacional de Jardines Infantiles (JUNJI)            AJ010
# 13180      Junta Nacional de Jardines Infantiles (JUNJI)            AJ010
# 87866                 Servicio Agricola y Ganadero (SAG)            AR006
# 104577                     Municipalidad de San Bernardo            MU281
# 8004         Servicio de Salud Metropolitano Sur Oriente            AO012
# 8005         Servicio de Salud Metropolitano Sur Oriente            AO012
# 103142                         Municipalidad de Santiago            MU308
# 14372                        Municipalidad de Huechuraba            MU109
# 10692                Subsecretaria de Economia (MINECON)            AH001
# 65358                         Municipalidad de Melipilla            MU173
# 19585                      Instituto Nacional del Cancer            AO108
# 19586                      Instituto Nacional del Cancer            AO108
# 19587                      Instituto Nacional del Cancer            AO108
# 130982                Corporacion Municipal de Melipilla            CM042
# 41497                 Subsecretaria de Transportes (MTT)            AN001
# 67128                          Subsecretaria de Hacienda            AE001
# 51521                             Municipalidad de Lampa            MU132
# 151184                       Municipalidad de Huechuraba            MU109
# 43655                              Hospital del Salvador            AO079
# 84293               Corporacion Municipal de Puente Alto            CM044
# 5438                    Direccion de Vialidad (VIALIDAD)            AM010
# 32566            Servicio de Salud Metropolitano Central            AO007
# 102167                                 Hospital San Jose            AO071
# 150017                    Municipalidad de Quinta Normal            MU257
# 113281              Corporacion Municipal de Cerro Navia            CM022
# 12200                         Municipalidad de Lo Espejo            MU145
# 145732                       Municipalidad de Huechuraba            MU109
#
#        fecha_publicacion  anyo    Mes              Nombres   Paterno Materno  \
# 11499         2021/09/10  2020  Abril        SERGIO HERNAN  GONZALEZ   PEREZ
# 96044         2021/08/31  2020  Abril        LUIS FERNANDO  GONZALEZ   PEREZ
# 92839         2021/09/14  2020  Abril         Karen Eliana  GONZALEZ   PEREZ
# 46014         2021/09/15  2020  Abril  CAROLINA DEL CARMEN  GONZALEZ   PEREZ
# 205978        2021/09/13  2020  Abril       MARIA GABRIELA  GONZALEZ   PEREZ
# 163166        2021/09/16  2020  Abril          VANESSA PAZ  GONZALEZ   PEREZ
# 92713         2021/08/30  2020  Abril     GRICELA CAROLINA  GONZALEZ   PEREZ
# 98051         2021/09/14  2020  Abril       SOLEDAD NICOLE  GONZALEZ   PEREZ
# 118280        2021/09/15  2020  Abril    MANUEL DEL CRISTO  GONZALEZ   PEREZ
# 118281        2021/09/15  2020  Abril    MANUEL DEL CRISTO  GONZALEZ   PEREZ
# 195072        2021/08/19  2020  Abril                MARIO  GONZALEZ   PEREZ
# 13863         2021/09/09  2020  Abril                MARIA  GONZALEZ   PEREZ
# 200054        2021/09/14  2020  Abril     SOFIA DEL CARMEN  GONZALEZ   PEREZ
# 142798        2021/09/14  2020  Abril          MARIA IRENE  GONZALEZ   PEREZ
# 189115        2021/09/10  2020  Abril         GASTON ARIEL  GONZALEZ   PEREZ
# 13179         2021/09/14  2020  Abril          ROSSE MARIE  GONZALEZ   PEREZ
# 13180         2021/09/14  2020  Abril               KARINA  GONZALEZ   PEREZ
# 87866         2021/09/13  2020  Abril          PABLO CESAR  GONZALEZ   PEREZ
# 104577        2021/09/14  2020  Abril             PATRICIA  GONZALEZ   PEREZ
# 8004          2021/09/07  2020  Abril    VALERIA FRANCISCA  GONZALEZ   PEREZ
# 8005          2021/09/07  2020  Abril    VALERIA FRANCISCA  GONZALEZ   PEREZ
# 103142        2021/09/15  2020  Abril     FRANCISCO JAVIER  GONZALEZ   PEREZ
# 14372         2021/09/10  2020  Abril          Jose Carlos  GONZALEZ   PEREZ
# 10692         2021/09/13  2020  Abril               MIRIAM  GONZALEZ   PEREZ
# 65358         2021/08/25  2020  Abril        BARBARA MABEL  GONZALEZ   PEREZ
# 19585         2021/09/10  2020  Abril   MACARENA ALEJANDRA  GONZALEZ   PEREZ
# 19586         2021/09/10  2020  Abril   MACARENA ALEJANDRA  GONZALEZ   PEREZ
# 19587         2021/09/10  2020  Abril   MACARENA ALEJANDRA  GONZALEZ   PEREZ
# 130982        2021/09/10  2020  Abril        SERGIO HERNAN  GONZALEZ   PEREZ
# 41497         2021/09/13  2020  Abril      RICARDO ESTEBAN  GONZALEZ   PEREZ
# 67128         2021/09/14  2020  Abril       Mario Bernardo  GONZALEZ   PEREZ
# 51521         2021/08/25  2020  Abril            GUILLERMO  GONZALEZ   PEREZ
# 151184        2021/09/13  2020  Abril          Jose Carlos  GONZALEZ   PEREZ
# 43655         2021/09/13  2020  Abril       ROSARIO CARMEN  GONZALEZ   PEREZ
# 84293         2021/08/31  2020  Abril     GLORIA DEL PILAR  GONZALEZ   PEREZ
# 5438          2021/09/10  2020  Abril    ELIANA DEL CARMEN  GONZALEZ   PEREZ
# 32566         2021/09/14  2020  Abril      MARIA RUBERTINA  GONZALEZ   PEREZ
# 102167        2021/09/14  2020  Abril          VICTOR HUGO  GONZALEZ   PEREZ
# 150017        2021/09/14  2020  Abril           ROSA PAOLA  GONZALEZ   PEREZ
# 113281        2021/09/14  2020  Abril              CLAUDIA  GONZALEZ   PEREZ
# 12200         2021/09/14  2020  Abril           ISABEL LUZ  GONZALEZ   PEREZ
# 145732        2021/09/09  2020  Abril            Maria Paz  GONZALEZ   PEREZ
#
#                                                Tipo cargo  ...  \
# 11499          ADMINPARADOCENTE EN DIRECCION DE EDUCACION  ...
# 96044       PROFESIONAL DE APOYO ADMINISTRACION EDUCACION  ...
# 92839   ATENCION DE PACIENTES HOSPITALIZADOS EN PEDIATRIA  ...
# 46014                              ADMINISTRATIVOS ESTAB.  ...
# 205978                                           AUXILIAR  ...
# 163166                                          PSICOLOGO  ...
# 92713                         ENCARGADOA DE ADQUISICIONES  ...
# 98051                                           ENFERMERA  ...
# 118280                                    CIRUGIA GENERAL  ...
# 118281                                    MEDICO CIRUJANO  ...
# 195072                          TRAUMATOLOGIA Y ORTOPEDIA  ...
# 13863         DOCENTE ESTUDIO SOCIAL VESPERTINA LICEO B69  ...
# 200054                                     ADMINISTRATIVO  ...
# 142798  ENCARGADA AREA ADMINISTRACION Y FINANZAS  SUBD...  ...
# 189115                              TECNICO DE ENFERMERIA  ...
# 13179                     TECNICO EN EDUCACION PARVULARIA  ...
# 13180   EDUCADORA DE PARVULOS FUNCION PEDAGOGICA EN JJ...  ...
# 87866               TECNICO SECTORIAL PROTECCION PECUARIA  ...
# 104577  ASISTENTE SOCIAL DEPARTAMENTO DE ASISTENCIA SO...  ...
# 8004                       TEC.PARAM. DE ENFER. NIVEL SUP  ...
# 8005                       TEC.PARAM. DE ENFER. NIVEL SUP  ...
# 103142                            DOCENTE ENSENANZA MEDIA  ...
# 14372          CONDUCTOR DE LA ADMINISTRACION  MUNICIPAL.  ...
# 10692                        SECRETARIA DIVISION JURIDICA  ...
# 65358                                                 NaN  ...
# 19585                                                 NaN  ...
# 19586                                                 NaN  ...
# 19587                                                 NaN  ...
# 130982                                                NaN  ...
# 41497                                                 NaN  ...
# 67128                                                 NaN  ...
# 51521                                                 NaN  ...
# 151184                                                NaN  ...
# 43655                                       APOYO CLINICO  ...
# 84293   TECNICO EN ENFERMERIA DE NIVEL SUPERIOR CENTRO...  ...
# 5438                            ASISTENTE TECNICO GENERAL  ...
# 32566                                APOYO ADMINISTRATIVO  ...
# 102167                                 TECNICO PARAMEDICO  ...
# 150017                         ASISTENTE SOCIAL DE DIDECO  ...
# 113281                                       ENFERMERO(A)  ...
# 12200     ADMINISTRATIVO DIRECCION DESARROLLO COMUNITARIO  ...
# 145732                 ADMINISTRATIVO EN RECURSOS HUMANOS  ...
#
#                   fecha_ingreso fecha_termino  \
# 11499                08/08/2011    Indefinido
# 96044                02/05/2018    Indefinido
# 92839                01/06/2002    Indefinido
# 46014                14/07/1997    Indefinido
# 205978               02/03/2009    31/12/2100
# 163166               01/03/2020    28/02/2021
# 92713                06/02/2003    31/12/2020
# 98051                01/01/2020    31/12/2020
# 118280               01/01/2020    31/12/2020
# 118281               01/01/2020    31/12/2020
# 195072               01/01/2020    31/12/2020
# 13863                01/03/2019    28/02/2021
# 200054               01/01/2020    31/12/2020
# 142798               01/01/2020    31/12/2020
# 189115               01/01/2020    31/12/2020
# 13179                04/07/2016    31/12/2020
# 13180                10/03/2012    31/12/2020
# 87866                01/01/2020    31/12/2020
# 104577               01/01/2020    31/12/2020
# 8004                 01/01/2020    31/12/2020
# 8005                 01/01/2020    31/12/2020
# 103142               13/09/2017    28/02/2021
# 14372                01/09/2018    30/06/2020
# 10692                01/01/2020    31/12/2020
# 65358   2020/03/01 00:00:00.000    31/03/2020
# 19585   2020/01/01 00:00:00.000    31/12/2020
# 19586   2020/01/01 00:00:00.000    31/12/2020
# 19587   2020/01/01 00:00:00.000    31/12/2020
# 130982  2020/02/01 00:00:00.000    30/06/2020
# 41497   2020/01/01 00:00:00.000    31/12/2020
# 67128   2020/02/03 00:00:00.000    31/12/2020
# 51521   2020/03/20 00:00:00.000    31/12/2020
# 151184  2020/01/01 00:00:00.000    30/06/2020
# 43655                01/12/2003    Indefinido
# 84293                01/12/2007    Indefinido
# 5438                 28/12/1978    Indefinido
# 32566                01/01/2017    Indefinido
# 102167               22/12/2003    30/04/2020
# 150017               16/04/1993    Indefinido
# 113281               01/02/2013    Indefinido
# 12200                01/07/2012    Indefinido
# 145732               01/06/2015    Indefinido
#
#                                             observaciones viaticos enlace  \
# 11499                                   Sin observaciones      NaN     No
# 96044                                   Sin observaciones      NaN     No
# 92839                                   Sin observaciones      0.0     No
# 46014                                   Sin Observaciones      NaN     No
# 205978                                  Sin observaciones      NaN     No
# 163166                                  Sin observaciones      0.0     No
# 92713   MONTO HORAS FESTIVAS CORRESPONDE A RECARGO DE ...      NaN     No
# 98051                                   Sin observaciones      NaN     No
# 118280                                  Sin observaciones      NaN     No
# 118281                                  Sin observaciones      NaN     No
# 195072                                                  9      NaN     No
# 13863                                   Sin observaciones      NaN     No
# 200054                                  Sin observaciones      NaN     No
# 142798                                  Sin observaciones      NaN     No
# 189115                                  SIN OBSERVACIONES      NaN     No
# 13179                                   Sin observaciones      NaN     No
# 13180                                   Sin observaciones      NaN     No
# 87866                                   Sin observaciones      NaN     No
# 104577                                  Sin observaciones      NaN     No
# 8004                                                   13      NaN     No
# 8005                                    Sin observaciones      NaN     No
# 103142                                  Sin Observaciones      NaN     No
# 14372   Funcionario media contrata con jornada de 22 h...      NaN     No
# 10692                                   Sin observaciones      0.0     No
# 65358                                       MARZO DE 2020      NaN     No
# 19585                                   Sin observaciones      NaN     No
# 19586                                   Sin observaciones      NaN     No
# 19587                                   Sin observaciones      NaN     No
# 130982                                  Sin observaciones      NaN     No
# 41497                                            42 Horas      NaN     No
# 67128                                   Sin observaciones      NaN     No
# 51521                                   Sin observaciones      NaN     No
# 151184                                  Sin observaciones      NaN     No
# 43655                                   Sin observaciones      0.0     No
# 84293                                   Sin observaciones      0.0     No
# 5438                                    Sin observaciones      0.0     No
# 32566                      Direccion de Atencion Primaria      0.0     No
# 102167                                  Sin observaciones      0.0     No
# 150017                                Movilizacion 39.945      0.0     No
# 113281                                  Sin observaciones      0.0     No
# 12200                                   Sin observaciones      0.0     No
# 145732                                  Sin observaciones      0.0     No
#
#         activado                                     Tipo Estamento  \
# 11499         SI                                                NaN
# 96044         SI                                                NaN
# 92839         SI                                                NaN
# 46014         SI                                                NaN
# 205978        SI                                                NaN
# 163166        SI                                                NaN
# 92713         SI                                     Administrativo
# 98051         SI                                        Profesional
# 118280        SI  Medicos cirujanos farmaceuticos quimicofarmace...
# 118281        SI  Medicos cirujanos farmaceuticos quimicofarmace...
# 195072        SI  Medicos cirujanos farmaceuticos quimicofarmace...
# 13863         SI                                            Docente
# 200054        SI                                     Administrativo
# 142798        SI                                        Profesional
# 189115        SI                                            Tecnico
# 13179         SI                                            Tecnico
# 13180         SI                                        Profesional
# 87866         SI                                            Tecnico
# 104577        SI                                        Profesional
# 8004          SI                                            Tecnico
# 8005          SI                                            Tecnico
# 103142        SI                                            Docente
# 14372         SI                                           Auxiliar
# 10692         SI                                     Administrativo
# 65358         SI                                                NaN
# 19585         SI                                                NaN
# 19586         SI                                                NaN
# 19587         SI                                                NaN
# 130982        SI                                                NaN
# 41497         SI                                                NaN
# 67128         SI                                                NaN
# 51521         SI                                                NaN
# 151184        SI                                                NaN
# 43655         SI                                           Auxiliar
# 84293         SI            Tecnicos de nivel superior (Ley 19.378)
# 5438          SI                                            Tecnico
# 32566         SI                                     Administrativo
# 102167        SI                                            Tecnico
# 150017        SI                                        Profesional
# 113281        SI                   Otros profesionales (Ley 19.378)
# 12200         SI                                     Administrativo
# 145732        SI                           Administrativos de Salud
#
#                                       descripcion_funcion  remuneracionbruta  \
# 11499                                                 NaN                NaN
# 96044                                                 NaN                NaN
# 92839                                                 NaN                NaN
# 46014                                                 NaN                NaN
# 205978                                                NaN                NaN
# 163166                                                NaN                NaN
# 92713                                                 NaN                NaN
# 98051                                                 NaN                NaN
# 118280                                                NaN                NaN
# 118281                                                NaN                NaN
# 195072                                                NaN                NaN
# 13863                                                 NaN                NaN
# 200054                                                NaN                NaN
# 142798                                                NaN                NaN
# 189115                                                NaN                NaN
# 13179                                                 NaN                NaN
# 13180                                                 NaN                NaN
# 87866                                                 NaN                NaN
# 104577                                                NaN                NaN
# 8004                                                  NaN                NaN
# 8005                                                  NaN                NaN
# 103142                                                NaN                NaN
# 14372                                                 NaN                NaN
# 10692                                                 NaN                NaN
# 65358   REALIZAR CLASES DE AEROBICA BAILE ENTRETENIDO ...           200000.0
# 19585                APOYO EN POLICLINICO DE RADIOTERAPIA         16807879.0
# 19586   APOYO EN POLICLINICO DE RADIOTERAPIA  HORAS EX...         16807879.0
# 19587            EXTENSION EN POLICLINICO DE RADIOTERAPIA         15000000.0
# 130982  PRUDUCCION MATERIAL AUDIOVISUAL DISENO GRAFICO...           277778.0
# 41497   Prestar Servicios en el Programa Nacional de F...           842265.0
# 67128                              Asesor Sicex  Hacienda          2600000.0
# 51521   Apoyo en Terreno al Servicio de Vigilancia Mun...           446000.0
# 151184  Gestionar llamados de vecinos sobre reclamos y...           492037.0
# 43655                                                 NaN                NaN
# 84293                                                 NaN                NaN
# 5438                                                  NaN                NaN
# 32566                                                 NaN                NaN
# 102167                                                NaN                NaN
# 150017                                                NaN                NaN
# 113281                                                NaN                NaN
# 12200                                                 NaN                NaN
# 145732                                                NaN                NaN
#
#         pago_mensuales
# 11499              NaN
# 96044              NaN
# 92839              NaN
# 46014              NaN
# 205978             NaN
# 163166             NaN
# 92713              NaN
# 98051              NaN
# 118280             NaN
# 118281             NaN
# 195072             NaN
# 13863              NaN
# 200054             NaN
# 142798             NaN
# 189115             NaN
# 13179              NaN
# 13180              NaN
# 87866              NaN
# 104577             NaN
# 8004               NaN
# 8005               NaN
# 103142             NaN
# 14372              NaN
# 10692              NaN
# 65358               Si
# 19585               Si
# 19586               Si
# 19587               Si
# 130982              Si
# 41497               Si
# 67128               Si
# 51521               Si
# 151184              Si
# 43655              NaN
# 84293              NaN
# 5438               NaN
# 32566              NaN
# 102167             NaN
# 150017             NaN
# 113281             NaN
# 12200              NaN
# 145732             NaN
#
# [42 rows x 33 columns]

# %%
p_g
# Out:
#                                                    camino  \
# 135310                                        /2020/Abril
# 183742            /Area de Atencion de Menores/2020/Abril
# 19597          /Hospital Clinico Institucional/2020/Abril
# 126114                /Educacion/Educacion Ano 2020/Abril
# 23107                                     /Ano 2020/Abril
# ...                                                   ...
# 54915                                         /2020/Abril
# 69662   /Docentes y Asistentes de la educacion/2020/Abril
# 186093                              /Salud/Ano 2020/Abril
# 33900                                   /Salud/2020/Abril
# 28005                               /Ano 2020/Salud/Abril
#
#                                          organismo_nombre organismo_codigo  \
# 135310         SEREMI de Salud  Metropolitano de Santiago            AO045
# 183742               Corporacion Municipal de Puente Alto            CM044
# 19597   Fuerza Aerea de Chile (Incluye al Servicio Aer...            AD008
# 126114                          Municipalidad de Penaflor            MU211
# 23107       Instituto Nacional de Derechos Humanos (INDH)            CO001
# ...                                                   ...              ...
# 54915                         Municipalidad de San Miguel            MU294
# 69662    Servicio Local de Educacion Publica de Barrancas            AJ016
# 186093                         Municipalidad de San Ramon            MU301
# 33900               Corporacion Municipal de San Bernardo            CM033
# 28005                     Corporacion Municipal de Colina            CM026
#
#        fecha_publicacion  anyo    Mes             Nombres Paterno   Materno  \
# 135310        2021/08/31  2020  Abril  GABRIELA MONSERRAT   PEREZ  GONZALEZ
# 183742        2021/08/31  2020  Abril     LUISA MAGDALENA   PEREZ  GONZALEZ
# 19597         2021/09/08  2020  Abril                Jose   PEREZ  GONZALEZ
# 126114        2021/09/16  2020  Abril       ROXANA ISABEL   PEREZ  GONZALEZ
# 23107         2021/09/14  2020  Abril         JUAN CARLOS   PEREZ  GONZALEZ
# ...                  ...   ...    ...                 ...     ...       ...
# 54915         2021/09/14  2020  Abril  SYLVIA DEL ROSARIO   PEREZ  GONZALEZ
# 69662         2021/09/13  2020  Abril      NATALIA ANDREA   PEREZ  GONZALEZ
# 186093        2021/09/15  2020  Abril              OTILIA   PEREZ  GONZALEZ
# 33900         2021/09/16  2020  Abril      CYNTHIA ISABEL   PEREZ  GONZALEZ
# 28005         2021/09/15  2020  Abril     ELENA DEL PILAR   PEREZ  GONZALEZ
#
#                                             Tipo cargo  ... fecha_ingreso  \
# 135310                    PROFESIONAL ALERTA SANITARIA  ...    01/03/2020
# 183742     EDUCADORA PEDAGOGICA JARD INF. CASAS VIEJAS  ...    13/11/2005
# 19597                                         OPERADOR  ...    01/02/2001
# 126114                   ENCARGADA AREA ABASTECIMIENTO  ...    18/03/2020
# 23107        TECNICO DE SOPORTE INFORMATICA Y SISTEMAS  ...    01/09/2014
# ...                                                ...  ...           ...
# 54915                          LABORES ADMINISTRATIVAS  ...    13/12/1991
# 69662                                          DOCENTE  ...    01/03/2018
# 186093                      TECNICOS DE NIVEL SUPERIOR  ...    01/03/2006
# 33900                                 ASISTENTE SOCIAL  ...    14/03/2005
# 28005   TECNICO EN ENFERMERIA POSTA RURAL LOS INGLESES  ...    16/01/2006
#
#        fecha_termino        observaciones viaticos enlace  activado  \
# 135310    31/05/2020    Sin observaciones      NaN     No        SI
# 183742    Indefinido    Sin observaciones      NaN     No        SI
# 19597     Indefinido    Sin observaciones      NaN     No        SI
# 126114    30/03/2020    Sin observaciones      NaN     No        SI
# 23107     Indefinido    Sin observaciones      NaN     No        SI
# ...              ...                  ...      ...    ...       ...
# 54915     31/12/2050    Sin observaciones      0.0     No        SI
# 69662     31/12/2100    Sin observaciones      0.0     No        SI
# 186093    Indefinido    Sin observaciones      0.0     No        SI
# 33900     Indefinido    Sin observaciones      0.0     No        SI
# 28005     Indefinido  44 HORAS TRABAJADAS      0.0     No        SI
#
#                                  Tipo Estamento  descripcion_funcion  \
# 135310                                      NaN                  NaN
# 183742                                      NaN                  NaN
# 19597                                       NaN                  NaN
# 126114                                      NaN                  NaN
# 23107                                       NaN                  NaN
# ...                                         ...                  ...
# 54915                                   Tecnico                  NaN
# 69662                                   Docente                  NaN
# 186093  Tecnicos de nivel superior (Ley 19.378)                  NaN
# 33900                               Profesional                  NaN
# 28005          Otros profesionales (Ley 19.378)                  NaN
#
#         remuneracionbruta  pago_mensuales
# 135310                NaN             NaN
# 183742                NaN             NaN
# 19597                 NaN             NaN
# 126114                NaN             NaN
# 23107                 NaN             NaN
# ...                   ...             ...
# 54915                 NaN             NaN
# 69662                 NaN             NaN
# 186093                NaN             NaN
# 33900                 NaN             NaN
# 28005                 NaN             NaN
#
# [62 rows x 33 columns]

# %%
a= metro.groupby(["Paterno", "Materno"]).size()
alls = a.index
for i in range(len(a)):
    if alls[i][0] == 'GONZALEZ' and alls[i][1] == 'PEREZ':
        print(a[i])
    if alls[i][0] == 'PEREZ' and alls[i][1] == 'GONZALEZ':
        print(a[i])
# Out:
# 42
# 62
