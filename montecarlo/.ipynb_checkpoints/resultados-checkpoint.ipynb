# %% [markdown]
# # #0

# %%
# ---- ¿Que año, mes y # de iteraciones quieres correr? ----
anyo = '2020'
mes = 'Abril'
iters = 100000

# %%
# ---- Librerías ---- 
import pandas as pd 
import numpy as np
import csv 
import warnings
import unicodedata
warnings.filterwarnings('ignore')

# %%
# ---- Método MonteCarlo ---- 
def MonteCarlo(population, sample_number, weights_column, 
                        current_distint_names, iterations):
    
    sum_distint_names = 0 #numero de apellidos distintos
    higher = 0       #veces que el # de apellidos simulado fue mayor al actual
    lower = 0        #veces que el # de apellidos simulado fue menor al actual
    equal = 0        #veces que el # de apellidos simulado fue igual al actual
    
    
    for i in range(0, iterations): #numero de iteraciones
        
        #esto saca un random example de la poblacion (general), le damos un "N" y un peso específico a cada apellido
        random_weighted_sample = population.sample(n = sample_number, replace = True, 
                                                   weights= weights_column, axis = 0)
        
        #sacamos el numero de apellidos distintos simulados
        distint_names = len(set(random_weighted_sample.index)) #Assuming index contains surnames
        
        
        sum_distint_names += distint_names
        
        
        if distint_names > current_distint_names:
            
            higher += 1

        elif distint_names < current_distint_names:
            
            lower += 1
        
        else:
            
            equal += 1
         
    #guardar output
    output = {'Employees': sample_number,
              'AVG Surnames': sum_distint_names/iterations, 
              'Current Surnames': current_distint_names, 
              '# Simulated > Current': higher, 
              '# Simulated < Current': lower, 
              '# Simulated = Current': equal, 
              'Iterations': iterations
             }
    
    return output

# %%
# ---- DB Apellidos Paternos ---- 
df_paternos = pd.read_excel('data publica/apellidos_paternos.xlsx', index_col=0, usecols = 'A:D',engine="openpyxl")

# %%
# ---- DB Instituciones ---- 
df_instituciones = pd.read_csv('data publica/Acronimos Organismos.csv', index_col=0, encoding="ISO-8859-1", delimiter =';')

# %%
# ---- DB Employees ---- 
df_whole = pd.read_csv('data publica/unidos/'+ mes + anyo + '.csv', index_col=0)

# %%
## ---------- Remover tildes de los apellidos y pasar a mayuscula ---------- ##
cols = df_paternos.select_dtypes(include=[np.object]).columns
df_paternos[cols] =df_paternos[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
cols = df_whole.select_dtypes(include=[np.object]).columns
df_whole[cols] =df_whole[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
df_whole['Paterno'] = df_whole['Paterno'].str.upper()
df_whole['Materno'] = df_whole['Materno'].str.upper()

# %%
## ---------- Apellidos Paternos x Región ---------- ##
pd.options.display.float_format = '{:,.2f}'.format 
df_paternos['AP PATERNO'] = df_paternos['AP PATERNO'].str.upper()
df_paternos_region = df_paternos[df_paternos['AP PATERNO'].notna()]
df_paternos_region = df_paternos_region.groupby(['REG','AP PATERNO']).agg({'CANTIDAD': "sum"}).sort_values(by=['CANTIDAD'], ascending=False)
df_paternos_region = df_paternos_region[df_paternos_region['CANTIDAD'] > 1]
df_paternos_region['CANTIDAD'] = df_paternos_region['CANTIDAD'].astype(int)
## ---------- Apellidos Paternos en Chile ---------- ##
df_paternos_region = df_paternos_region.reset_index(level=['REG'])
df_paternos_total = df_paternos_region.groupby(['AP PATERNO']).agg({'CANTIDAD': "sum"}).sort_values(by=['CANTIDAD'], ascending=False)
df_paternos_total['PORCENTAJE'] = (df_paternos_total['CANTIDAD']/df_paternos_total['CANTIDAD'].sum())
df_paternos_total['CANTIDAD'] = df_paternos_total['CANTIDAD'].astype(int)
df_paternos_total = df_paternos_total.dropna()
df_paternos_total = df_paternos_total[df_paternos_total['CANTIDAD'] > 1]

# %%
df_paternos_total
# Out:
#             CANTIDAD  PORCENTAJE
# AP PATERNO
# GONZALEZ      444542        0.02
# MUNOZ         349675        0.02
# ROJAS         249660        0.01
# DIAZ          246901        0.01
# PEREZ         196733        0.01
# ...              ...         ...
# CANOBA             2        0.00
# CANNY              2        0.00
# CANNIZZO           2        0.00
# GARIZADO           2        0.00
# LASSERE            2        0.00
#
# [60603 rows x 2 columns]

# %%
region_codes = {'Region Metropolitana de Santiago':13,
                'Region de Antofagasta':2,
                'Region de Arica y Parinacota':15,
                'Region de Atacama':3,
                'Region de Aysen':11,
                'Region de Coquimbo':4,
                'Region de La Araucania':9,
                'Region de Los Lagos':10,
                'Region de Los Rios':14,
                'Region de Magallanes':12,
                'Region de Nuble':16,
                'Region de OHiggins':6,
                'Region de Tarapaca':1,
                'Region de Valparaiso':5,
                'Region del Biobio':8,
                'Region del Maule':7}

# %% [markdown]
# # #1 Todos

# %%
#numero de apellidos unicos en el organismo
distint_names_organismo = len(set(df_whole['Paterno'].value_counts().index)) 

#numero de personas en el organismo
total = len(df_whole['Paterno'])

#saca todos los apellidos de la región
population = df_paternos_total

#El peso de los apellidos de la región
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

#Ejecutar MonteCarlo
output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_organismo, iters)

# %%
output
# Out:
# {'Employees': 681204,
#  'AVG Surnames': 23305.68638,
#  'Current Surnames': 23427,
#  '# Simulated > Current': 7772,
#  '# Simulated < Current': 92054,
#  '# Simulated = Current': 174,
#  'Iterations': 100000}

# %% [markdown]
# # #2 Area

# %%
df_merged = pd.merge(df_whole, df_instituciones, left_on='organismo_codigo', right_on='Codigo_org', how='inner')
areas = set(df_merged['Padre_org'].value_counts().index)

# %%
dict_regiones = { 'Defensa Nacional' : 'All' ,
'Vivienda y Urbanismo' : 'All' ,
'Municipios de Tarapacá' : 'Region de Tarapaca' ,
'Municipios de Atacama' : 'Region de Atacama' ,
'Minería' : 'All' ,
'Medio Ambiente' : 'All' ,
'Educación' : 'All' ,
'Transportes y Telecomunicaciones' : 'All' ,
'Asociación Municipal' : 'All' ,
'Salud' : 'All' ,
'Agricultura' : 'All' ,
'Municipios de Los Lagos' : 'Region de Los Lagos' ,
'La Mujer y Equidad de Género' : 'All' ,
'Municipios de R. Metropolitana de Santiago' : 'Region Metropolitana de Santiago' ,
'Deporte' : 'All' ,
'Secretaría General de Gobierno' : 'All' ,
'Centro de Formación Técnica' : 'All' ,
'Bienes Nacionales' : 'All' ,
'Secretaría General de la Presidencia' : 'All' ,
'Universidades' : 'All' ,
'Municipios del Libertador General Bernardo OHiggins' : 'Region de OHiggins' ,
'Interior y Seguridad Pública' : 'All' ,
'Municipios de Aysen del General Carlos Ibáñez del Campo' : 'Region de Aysen' ,
'Defensoría de los Derechos de la Niñez' : 'All' ,
'Energía' : 'All' ,
'Municipios de Antofagasta' : 'Region de Antofagasta' ,
'Justicia' : 'All' ,
'Municipios del Bíobio' : 'Region del Biobio' ,
'Corporaciones Municipales' : 'All' ,
'Municipios de La Araucanía' : 'Region de La Araucania' ,
'Municipios de Valparaíso' : 'All' ,
'Consejo Defensa del Estado' : 'All' ,
'Municipios de Ñuble' : 'All' ,
'Municipios de Arica y  Parinacota' : 'Region de Arica y Parinacota' ,
'Superintendencia de Servicios Sanitarios' : 'All' ,
'Municipios de Magallanes y de la Antártica Chilena' : 'Region de Magallanes' ,
'Economía Fomento y Turismo' : 'All' ,
'Municipios del Maule' : 'Region del Maule' ,
'Desarrollo Social' : 'All' ,
'Presidencia de la República' : 'All' ,
'Municipios de Los Ríos' : 'Region de Los Rios' ,
'Trabajo y Previsión Social' : 'All' ,
'Fundaciones y corporaciones' : 'All' ,
'Culturas y las Artes' : 'All' ,
'Hacienda' : 'All' ,
'Municipios de Coquimbo' : 'Region de Coquimbo' ,
'Instituto Derechos Humanos' : 'All' ,
'Obras Públicas' : 'All' ,
'Ciencia Tecnología e Innovación' : 'All' ,
'Consejo para la Transparencia' : 'All' ,
'Relaciones Exteriores' : 'All'
}

# %%
dict_areas = {}

for area in areas:
    
    #Se filtra la planta por area
    df_area = df_merged[df_merged['Padre_org'] == area]    

    #Número de personas en el área
    totalOrg = len(df_area['Paterno'])
    
    #Si el área tiene más de cien personas
    if totalOrg > 30 :
        
        #Top 10%
        distint_names_area = len(set(df_area['Paterno'].value_counts().index))
        total = len(df_area['Paterno'])    
        region = df_area['region']
        regiones = set(region)
        lenght = len(regiones)
        regiones = list(val for val in regiones)

        if lenght == 1:
            region = regiones[0]
            region = unicodedata.normalize("NFKD",region).encode("ascii","ignore").decode("ascii")
            code_region = region_codes[region]  
            population = df_paternos_region[df_paternos_region['REG'] == code_region] 
        
        #Composición toda la poblacion
        else:
            import unicodedata
            population = df_paternos_total

        population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
        output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_area, iters)
        
        dict_areas[area] = output

# %%
dict_areas
# Out:
# {'Trabajo y Previsión Social': {'Employees': 8062,
#   'AVG Surnames': 1830.17692,
#   'Current Surnames': 1843,
#   '# Simulated > Current': 32016,
#   '# Simulated < Current': 66732,
#   '# Simulated = Current': 1252,
#   'Iterations': 100000},
#  'Obras Públicas': {'Employees': 9123,
#   'AVG Surnames': 1972.12345,
#   'Current Surnames': 1898,
#   '# Simulated > Current': 99357,
#   '# Simulated < Current': 581,
#   '# Simulated = Current': 62,
#   'Iterations': 100000},
#  'Superintendencia de Servicios Sanitarios': {'Employees': 204,
#   'AVG Surnames': 160.28071,
#   'Current Surnames': 155,
#   '# Simulated > Current': 80635,
#   '# Simulated < Current': 14782,
#   '# Simulated = Current': 4583,
#   'Iterations': 100000},
#  'Municipios del Libertador General Bernardo OHiggins': {'Employees': 18772,
#   'AVG Surnames': 1534.84801,
#   'Current Surnames': 1772,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Instituto Derechos Humanos': {'Employees': 194,
#   'AVG Surnames': 153.84156,
#   'Current Surnames': 156,
#   '# Simulated > Current': 31436,
#   '# Simulated < Current': 61694,
#   '# Simulated = Current': 6870,
#   'Iterations': 100000},
#  'Defensoría de los Derechos de la Niñez': {'Employees': 51,
#   'AVG Surnames': 47.38315,
#   'Current Surnames': 47,
#   '# Simulated > Current': 50667,
#   '# Simulated < Current': 29556,
#   '# Simulated = Current': 19777,
#   'Iterations': 100000},
#  'Transportes y Telecomunicaciones': {'Employees': 2082,
#   'AVG Surnames': 811.1992,
#   'Current Surnames': 840,
#   '# Simulated > Current': 4612,
#   '# Simulated < Current': 94817,
#   '# Simulated = Current': 571,
#   'Iterations': 100000},
#  'Municipios de Los Lagos': {'Employees': 24601,
#   'AVG Surnames': 2893.35266,
#   'Current Surnames': 2583,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Economía Fomento y Turismo': {'Employees': 7051,
#   'AVG Surnames': 1688.61309,
#   'Current Surnames': 1925,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Valparaíso': {'Employees': 25183,
#   'AVG Surnames': 3672.39913,
#   'Current Surnames': 2787,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Relaciones Exteriores': {'Employees': 280,
#   'AVG Surnames': 206.33391,
#   'Current Surnames': 221,
#   '# Simulated > Current': 1194,
#   '# Simulated < Current': 98257,
#   '# Simulated = Current': 549,
#   'Iterations': 100000},
#  'Municipios del Maule': {'Employees': 32689,
#   'AVG Surnames': 1779.26549,
#   'Current Surnames': 2113,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Bienes Nacionales': {'Employees': 762,
#   'AVG Surnames': 426.79755,
#   'Current Surnames': 441,
#   '# Simulated > Current': 10040,
#   '# Simulated < Current': 88340,
#   '# Simulated = Current': 1620,
#   'Iterations': 100000},
#  'Educación': {'Employees': 46951,
#   'AVG Surnames': 5393.62113,
#   'Current Surnames': 4745,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Arica y  Parinacota': {'Employees': 298,
#   'AVG Surnames': 211.58732,
#   'Current Surnames': 168,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Coquimbo': {'Employees': 16155,
#   'AVG Surnames': 1438.32009,
#   'Current Surnames': 1596,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Universidades': {'Employees': 944,
#   'AVG Surnames': 492.28116,
#   'Current Surnames': 494,
#   '# Simulated > Current': 42990,
#   '# Simulated < Current': 53863,
#   '# Simulated = Current': 3147,
#   'Iterations': 100000},
#  'Salud': {'Employees': 199403,
#   'AVG Surnames': 12629.06099,
#   'Current Surnames': 12529,
#   '# Simulated > Current': 91510,
#   '# Simulated < Current': 8280,
#   '# Simulated = Current': 210,
#   'Iterations': 100000},
#  'Municipios de R. Metropolitana de Santiago': {'Employees': 56459,
#   'AVG Surnames': 6724.67464,
#   'Current Surnames': 5225,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Consejo para la Transparencia': {'Employees': 161,
#   'AVG Surnames': 131.74802,
#   'Current Surnames': 134,
#   '# Simulated > Current': 28307,
#   '# Simulated < Current': 63920,
#   '# Simulated = Current': 7773,
#   'Iterations': 100000},
#  'Energía': {'Employees': 1474,
#   'AVG Surnames': 655.18566,
#   'Current Surnames': 619,
#   '# Simulated > Current': 99075,
#   '# Simulated < Current': 766,
#   '# Simulated = Current': 159,
#   'Iterations': 100000},
#  'Vivienda y Urbanismo': {'Employees': 6298,
#   'AVG Surnames': 1577.80854,
#   'Current Surnames': 1663,
#   '# Simulated > Current': 51,
#   '# Simulated < Current': 99933,
#   '# Simulated = Current': 16,
#   'Iterations': 100000},
#  'Municipios de Los Ríos': {'Employees': 8163,
#   'AVG Surnames': 1377.573,
#   'Current Surnames': 1368,
#   '# Simulated > Current': 68579,
#   '# Simulated < Current': 29554,
#   '# Simulated = Current': 1867,
#   'Iterations': 100000},
#  'Desarrollo Social': {'Employees': 3626,
#   'AVG Surnames': 1134.03895,
#   'Current Surnames': 1328,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Interior y Seguridad Pública': {'Employees': 4599,
#   'AVG Surnames': 1307.19064,
#   'Current Surnames': 1434,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Deporte': {'Employees': 3838,
#   'AVG Surnames': 1173.12022,
#   'Current Surnames': 1135,
#   '# Simulated > Current': 95948,
#   '# Simulated < Current': 3677,
#   '# Simulated = Current': 375,
#   'Iterations': 100000},
#  'Consejo Defensa del Estado': {'Employees': 633,
#   'AVG Surnames': 375.96108,
#   'Current Surnames': 387,
#   '# Simulated > Current': 13801,
#   '# Simulated < Current': 83973,
#   '# Simulated = Current': 2226,
#   'Iterations': 100000},
#  'Municipios de Aysen del General Carlos Ibáñez del Campo': {'Employees': 4530,
#   'AVG Surnames': 964.50564,
#   'Current Surnames': 1101,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Culturas y las Artes': {'Employees': 3247,
#   'AVG Surnames': 1061.374,
#   'Current Surnames': 1203,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Hacienda': {'Employees': 5937,
#   'AVG Surnames': 1522.95224,
#   'Current Surnames': 1588,
#   '# Simulated > Current': 490,
#   '# Simulated < Current': 99443,
#   '# Simulated = Current': 67,
#   'Iterations': 100000},
#  'Minería': {'Employees': 914,
#   'AVG Surnames': 481.9158,
#   'Current Surnames': 522,
#   '# Simulated > Current': 61,
#   '# Simulated < Current': 99907,
#   '# Simulated = Current': 32,
#   'Iterations': 100000},
#  'Municipios de La Araucanía': {'Employees': 20805,
#   'AVG Surnames': 2748.06996,
#   'Current Surnames': 2534,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Antofagasta': {'Employees': 2914,
#   'AVG Surnames': 925.25878,
#   'Current Surnames': 788,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Fundaciones y corporaciones': {'Employees': 272,
#   'AVG Surnames': 201.75501,
#   'Current Surnames': 193,
#   '# Simulated > Current': 89155,
#   '# Simulated < Current': 8338,
#   '# Simulated = Current': 2507,
#   'Iterations': 100000},
#  'Municipios de Ñuble': {'Employees': 17162,
#   'AVG Surnames': 2899.34432,
#   'Current Surnames': 1832,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios de Atacama': {'Employees': 4033,
#   'AVG Surnames': 892.58472,
#   'Current Surnames': 884,
#   '# Simulated > Current': 68050,
#   '# Simulated < Current': 29841,
#   '# Simulated = Current': 2109,
#   'Iterations': 100000},
#  'Justicia': {'Employees': 12977,
#   'AVG Surnames': 2443.1022,
#   'Current Surnames': 2444,
#   '# Simulated > Current': 48285,
#   '# Simulated < Current': 50512,
#   '# Simulated = Current': 1203,
#   'Iterations': 100000},
#  'Agricultura': {'Employees': 7288,
#   'AVG Surnames': 1722.47009,
#   'Current Surnames': 1784,
#   '# Simulated > Current': 1245,
#   '# Simulated < Current': 98641,
#   '# Simulated = Current': 114,
#   'Iterations': 100000},
#  'Ciencia Tecnología e Innovación': {'Employees': 116,
#   'AVG Surnames': 99.54529,
#   'Current Surnames': 103,
#   '# Simulated > Current': 13941,
#   '# Simulated < Current': 78619,
#   '# Simulated = Current': 7440,
#   'Iterations': 100000},
#  'Corporaciones Municipales': {'Employees': 63973,
#   'AVG Surnames': 6515.04798,
#   'Current Surnames': 6086,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Medio Ambiente': {'Employees': 1266,
#   'AVG Surnames': 595.13762,
#   'Current Surnames': 635,
#   '# Simulated > Current': 253,
#   '# Simulated < Current': 99674,
#   '# Simulated = Current': 73,
#   'Iterations': 100000},
#  'Secretaría General de Gobierno': {'Employees': 778,
#   'AVG Surnames': 432.78371,
#   'Current Surnames': 465,
#   '# Simulated > Current': 259,
#   '# Simulated < Current': 99658,
#   '# Simulated = Current': 83,
#   'Iterations': 100000},
#  'Defensa Nacional': {'Employees': 15161,
#   'AVG Surnames': 2686.8051,
#   'Current Surnames': 2821,
#   '# Simulated > Current': 7,
#   '# Simulated < Current': 99993,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Secretaría General de la Presidencia': {'Employees': 349,
#   'AVG Surnames': 244.39245,
#   'Current Surnames': 263,
#   '# Simulated > Current': 668,
#   '# Simulated < Current': 99028,
#   '# Simulated = Current': 304,
#   'Iterations': 100000},
#  'Presidencia de la República': {'Employees': 468,
#   'AVG Surnames': 303.58593,
#   'Current Surnames': 319,
#   '# Simulated > Current': 4098,
#   '# Simulated < Current': 94847,
#   '# Simulated = Current': 1055,
#   'Iterations': 100000},
#  'Centro de Formación Técnica': {'Employees': 359,
#   'AVG Surnames': 249.64725,
#   'Current Surnames': 244,
#   '# Simulated > Current': 74475,
#   '# Simulated < Current': 21684,
#   '# Simulated = Current': 3841,
#   'Iterations': 100000},
#  'Asociación Municipal': {'Employees': 448,
#   'AVG Surnames': 294.06731,
#   'Current Surnames': 290,
#   '# Simulated > Current': 65703,
#   '# Simulated < Current': 30274,
#   '# Simulated = Current': 4023,
#   'Iterations': 100000},
#  'La Mujer y Equidad de Género': {'Employees': 624,
#   'AVG Surnames': 372.22372,
#   'Current Surnames': 407,
#   '# Simulated > Current': 29,
#   '# Simulated < Current': 99955,
#   '# Simulated = Current': 16,
#   'Iterations': 100000},
#  'Municipios de Magallanes y de la Antártica Chilena': {'Employees': 1531,
#   'AVG Surnames': 588.4878,
#   'Current Surnames': 555,
#   '# Simulated > Current': 98661,
#   '# Simulated < Current': 1137,
#   '# Simulated = Current': 202,
#   'Iterations': 100000},
#  'Municipios de Tarapacá': {'Employees': 1870,
#   'AVG Surnames': 789.57311,
#   'Current Surnames': 674,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Municipios del Bíobio': {'Employees': 36081,
#   'AVG Surnames': 2559.39599,
#   'Current Surnames': 2677,
#   '# Simulated > Current': 16,
#   '# Simulated < Current': 99983,
#   '# Simulated = Current': 1,
#   'Iterations': 100000}}

# %%
nombre_archivo = 'resultados/3-areas-{0}.csv'.format(iters)
data = [] 
columns = []

for key, value in dict_areas.items():
    data.append(value)
    columns.append(key)
    
total = pd.DataFrame(data, index = columns) 
total.to_csv(nombre_archivo)

# %% [markdown]
# # #3 Contrato

# %%
df_planta = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Planta.csv', index_col=0)
df_honorarios = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Honorarios.csv', index_col=0)
df_contrata = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Contrata.csv', index_col=0)
df_codigotrabajo = pd.read_csv('data publica/por contrato/'+ mes + anyo + 'Codigotrabajo.csv', index_col=0)

# %%
surnames_planta = len(set(df_planta['Paterno'].value_counts().index))
total_planta = len(df_planta['Paterno'])
surnames_contrata = len(set(df_contrata['Paterno'].value_counts().index))
total_contrata = len(df_contrata['Paterno'])
surnames_honorarios = len(set(df_honorarios['Paterno'].value_counts().index))
total_honorarios = len(df_honorarios['Paterno'])
surnames_codigotrabajo = len(set(df_codigotrabajo['Paterno'].value_counts().index))
total_codigotrabajo = len(df_codigotrabajo['Paterno'])
population = df_paternos_total
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

output_planta = MonteCarlo(population, total_planta, 'PORCENTAJE', surnames_planta, iters)
output_contrata = MonteCarlo(population, total_contrata, 'PORCENTAJE', surnames_contrata, iters)
output_honorarios = MonteCarlo(population, total_honorarios, 'PORCENTAJE', surnames_honorarios, iters)
output_codigotrabajo = MonteCarlo(population, total_codigotrabajo, 'PORCENTAJE', surnames_codigotrabajo, iters)

# %%
output_planta, output_contrata, output_honorarios, output_codigotrabajo
# Out:
# ({'Employees': 162505,
#   'AVG Surnames': 11269.87699,
#   'Current Surnames': 12326,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 298139,
#   'AVG Surnames': 15658.3966,
#   'Current Surnames': 19512,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 109785,
#   'AVG Surnames': 8994.38081,
#   'Current Surnames': 12302,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 110775,
#   'AVG Surnames': 9041.53954,
#   'Current Surnames': 10136,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000})

# %% [markdown]
# # #4 Region

# %%
#Dictionario con los resultados
dict_regiones = {}

#Para cada organismo
for region in region_codes:
    
    df_region = df_whole[df_whole['region'] == region]

    #numero de apellidos unicos en el organismo
    distint_names_region = len(set(df_region['Paterno'].value_counts().index))

    #numero de personas en el organismo
    total = len(df_region['Paterno'])
        
    import unicodedata
    region = unicodedata.normalize("NFKD",region).encode("ascii","ignore").decode("ascii")

    #codigo de la región
    code_region = region_codes[region]  
    
    #saca todos los apellidos de la región
    population = df_paternos_region[df_paternos_region['REG'] == code_region]
    
    #El peso de los apellidos de la región
    population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
    
    #Ejecutar MonteCarlo
    output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_region, iters)
    
    #Guardar resultado
    dict_regiones[region] = output

# %%
dict_regiones
# Out:
# {'Region Metropolitana de Santiago': {'Employees': 220135,
#   'AVG Surnames': 15123.39028,
#   'Current Surnames': 13537,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Antofagasta': {'Employees': 22753,
#   'AVG Surnames': 2691.67854,
#   'Current Surnames': 2841,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Arica y Parinacota': {'Employees': 9885,
#   'AVG Surnames': 1571.42246,
#   'Current Surnames': 1875,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Atacama': {'Employees': 13361,
#   'AVG Surnames': 1529.39419,
#   'Current Surnames': 1711,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Aysen': {'Employees': 11405,
#   'AVG Surnames': 1413.80393,
#   'Current Surnames': 1889,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Coquimbo': {'Employees': 32685,
#   'AVG Surnames': 1966.22197,
#   'Current Surnames': 2608,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de La Araucania': {'Employees': 41960,
#   'AVG Surnames': 3699.11691,
#   'Current Surnames': 3922,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Los Lagos': {'Employees': 46666,
#   'AVG Surnames': 3851.78632,
#   'Current Surnames': 4032,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Los Rios': {'Employees': 17301,
#   'AVG Surnames': 1801.10433,
#   'Current Surnames': 2435,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Magallanes': {'Employees': 8051,
#   'AVG Surnames': 1586.69152,
#   'Current Surnames': 1661,
#   '# Simulated > Current': 82,
#   '# Simulated < Current': 99909,
#   '# Simulated = Current': 9,
#   'Iterations': 100000},
#  'Region de Nuble': {'Employees': 24952,
#   'AVG Surnames': 188.0,
#   'Current Surnames': 2271,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de OHiggins': {'Employees': 37026,
#   'AVG Surnames': 2075.97652,
#   'Current Surnames': 2891,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region de Tarapaca': {'Employees': 9679,
#   'AVG Surnames': 1992.19907,
#   'Current Surnames': 2068,
#   '# Simulated > Current': 199,
#   '# Simulated < Current': 99784,
#   '# Simulated = Current': 17,
#   'Iterations': 100000},
#  'Region de Valparaiso': {'Employees': 64556,
#   'AVG Surnames': 5052.04864,
#   'Current Surnames': 5567,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region del Biobio': {'Employees': 72123,
#   'AVG Surnames': 3602.88941,
#   'Current Surnames': 4225,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  'Region del Maule': {'Employees': 48666,
#   'AVG Surnames': 2115.39025,
#   'Current Surnames': 2849,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000}}

# %%
nombre_archivo = 'resultados/4-regiones-{0}.csv'.format(iters)
data = [] 
columns = []

for key, value in dict_regiones.items():
    data.append(value)
    columns.append(key)
    
total = pd.DataFrame(data, index = columns) 
total.to_csv(nombre_archivo)

# %% [markdown]
# # #5 By decil

# %%
#Dictionario con los resultados
dict_organismos = {}

#Generar deciles en base a la remuneración bruta
df_whole['decilePlanta'] = pd.qcut(df_whole['remuneracionbruta_mensual'], 10, labels=False, duplicates='drop')
    
#Total de empleados en ese organismo
totalAll = len(df_whole['Paterno'])
    
#Decil Top
topDecil = df_whole[df_whole['decilePlanta'] == 9]
    
#Decil bottom
bottomDecil = df_whole[df_whole['decilePlanta'] == 0]
    
#---------------------------Para el top 10% --------------------------#
        
#Cantidad única de apellidos
distint_names_organismo = len(set(topDecil['Paterno'].value_counts().index))
        
#Cantidad de personas en el decil top
totalTop = len(topDecil['Paterno'])
        
#Población de esa región
population = df_paternos_total 
        
#Sacamos los pesos de cada apellido i.e, el porcentaje en esa región
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
        
#Corremos la Monte Carlo
outputTop = MonteCarlo(population, totalTop, 'PORCENTAJE', distint_names_organismo, iters)
        
#---------------------------Para el bottom 10% --------------------------#

#Para el bottom 90%
distint_names_organismo = len(set(bottomDecil['Paterno'].value_counts().index))
        
totalBottom = len(bottomDecil['Paterno'])
                
outputBottom = MonteCarlo(population, totalBottom, 'PORCENTAJE', distint_names_organismo, iters)

# %%
outputTop, outputBottom
# Out:
# ({'Employees': 57141,
#   'AVG Surnames': 6082.36164,
#   'Current Surnames': 8006,
#   '# Simulated > Current': 0,
#   '# Simulated < Current': 100000,
#   '# Simulated = Current': 0,
#   'Iterations': 100000},
#  {'Employees': 57142,
#   'AVG Surnames': 6082.65167,
#   'Current Surnames': 4946,
#   '# Simulated > Current': 100000,
#   '# Simulated < Current': 0,
#   '# Simulated = Current': 0,
#   'Iterations': 100000})

# %%
#Generar deciles en base a la remuneración bruta
dict_deciles = {}
df_whole['decilePlanta'] = pd.qcut(df_whole['remuneracionbruta_mensual'], 10, labels=False, duplicates='drop')
    
#Población
population = df_paternos_total 
        
#Sacamos los pesos de cada apellido i.e, el porcentaje en esa región
population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

for i in range (0, 10):
    
    Decil = df_whole[df_whole['decilePlanta'] == i]
    
    #Apellidos unicos en el decil
    distint_names_decil = len(set(Decil['Paterno'].value_counts().index))
        
    #Cantidad de personas en el decil top
    totalDecil = len(Decil['Paterno'])
        
    #Corremos la Monte Carlo
    output = MonteCarlo(population, totalDecil, 'PORCENTAJE', distint_names_decil, iters)
        
    dict_deciles[i] = output
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-39abe3e5aee7> in <module>
#      20
#      21     #Corremos la Monte Carlo
# ---> 22     output = MonteCarlo(population, totalDecil, 'PORCENTAJE', distint_names_decil, iters)
#      23
#      24     dict_deciles[i] = output
#
# <ipython-input-47-44e5dc73a2ce> in MonteCarlo(population, sample_number, weights_column, current_distint_names, iterations)
#      12
#      13         #esto saca un random example de la poblacion (general), le damos un "N" y un peso específico a cada apellido
# ---> 14         random_weighted_sample = population.sample(n = sample_number, replace = True,
#      15                                                    weights= weights_column, axis = 0)
#      16
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4991             )
#    4992
# -> 4993         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4994         return self.take(locs, axis=axis)
#    4995
#
# KeyboardInterrupt:

# %%
dict_deciles

# %%
df_whole['decilePlanta'] = pd.qcut(df_whole['remuneracionbruta_mensual'], 10, labels=False, duplicates='drop')

# %%
#Remuneración por decil
for i in range(0, 10):
    print(df_whole[df_whole['decilePlanta'] == i]['remuneracionbruta_mensual'].mean())

# %% [markdown]
# # #6 By organism

# %%
#Loop para cada organismo

dict_organismos = {}
organismos = set(df_whole['organismo_codigo'])

for organismo in organismos:
    
    #Se filtra los empleados por organismo
    df_organismo = df_whole[df_whole['organismo_codigo'] == organismo]    

    #Número de personas en el organismo
    total = len(df_organismo['Paterno'])    
    
    distint_names_org = len(set(df_organismo['Paterno'].value_counts().index))

    #Sacamos la region
    region = df_organismo['region']
    regiones = set(region)
    lenght = len(regiones)
    
    
    try:
        if lenght == 1 and total > 1:
            regiones = list(val for val in regiones)
            region = regiones[0]
            region = unicodedata.normalize("NFKD",region).encode("ascii","ignore").decode("ascii")
            code_region = region_codes[region]  
            population = df_paternos_region[df_paternos_region['REG'] == code_region] 
            population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()

            #MonteCarlo
            
            output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_org, iters)
            dict_organismos[organismo] = output
            print(organismo, output)

        #Composición toda la poblacion, para los embedding usamos la RM
        elif total > 1:
            code_region = 13
            population = df_paternos_total
            population['PORCENTAJE'] = population['CANTIDAD']/population['CANTIDAD'].sum()
            
            #MonteCarlo
    
            output = MonteCarlo(population, total, 'PORCENTAJE', distint_names_org, iters)
            dict_organismos[organismo] = output
            print(organismo, output)

        else:
            print(organismo, ' solo un empleado')
    
    except Exception as e:
        print(organismo, e, ' da error ')
# Out:
# AQ001 {'Employees': 762, 'AVG Surnames': 426.83913, 'Current Surnames': 441, '# Simulated > Current': 10110, '# Simulated < Current': 88247, '# Simulated = Current': 1643, 'Iterations': 100000}
# AM005 {'Employees': 401, 'AVG Surnames': 271.11091, 'Current Surnames': 274, '# Simulated > Current': 34331, '# Simulated < Current': 61219, '# Simulated = Current': 4450, 'Iterations': 100000}
# MU164 {'Employees': 504, 'AVG Surnames': 262.28323, 'Current Surnames': 248, '# Simulated > Current': 94325, '# Simulated < Current': 4466, '# Simulated = Current': 1209, 'Iterations': 100000}
# MU235 {'Employees': 332, 'AVG Surnames': 214.35386, 'Current Surnames': 193, '# Simulated > Current': 99624, '# Simulated < Current': 255, '# Simulated = Current': 121, 'Iterations': 100000}
# AO045 {'Employees': 1063, 'AVG Surnames': 539.47977, 'Current Surnames': 525, '# Simulated > Current': 85041, '# Simulated < Current': 13213, '# Simulated = Current': 1746, 'Iterations': 100000}
# MA022 {'Employees': 3, 'AVG Surnames': 2.98774, 'Current Surnames': 3, '# Simulated > Current': 0, '# Simulated < Current': 1221, '# Simulated = Current': 98779, 'Iterations': 100000}
# AJ020 {'Employees': 2193, 'AVG Surnames': 862.19667, 'Current Surnames': 685, '# Simulated > Current': 100000, '# Simulated < Current': 0, '# Simulated = Current': 0, 'Iterations': 100000}
# MU049 {'Employees': 315, 'AVG Surnames': 206.18459, 'Current Surnames': 152, '# Simulated > Current': 100000, '# Simulated < Current': 0, '# Simulated = Current': 0, 'Iterations': 100000}
#
# AO058 {'Employees': 1800, 'AVG Surnames': 706.60424, 'Current Surnames': 718, '# Simulated > Current': 21400, '# Simulated < Current': 76610, '# Simulated = Current': 1990, 'Iterations': 100000}
# AO035 {'Employees': 1566, 'AVG Surnames': 617.68557, 'Current Surnames': 624, '# Simulated > Current': 32820, '# Simulated < Current': 64803, '# Simulated = Current': 2377, 'Iterations': 100000}
# AP011 {'Employees': 201, 'AVG Surnames': 162.1308, 'Current Surnames': 157, '# Simulated > Current': 80843, '# Simulated < Current': 14551, '# Simulated = Current': 4606, 'Iterations': 100000}
# MA027 {'Employees': 4, 'AVG Surnames': 3.9805, 'Current Surnames': 4, '# Simulated > Current': 0, '# Simulated < Current': 1935, '# Simulated = Current': 98065, 'Iterations': 100000}

# %%
nombre_archivo = 'resultados/6-organismos-{0}.csv'.format(iters)
data = [] 
columns = []

for key, value in dict_organismos.items():
    data.append(value)
    columns.append(key)
    
total = pd.DataFrame(data, index = columns) 
total.to_csv(nombre_archivo)

# %% [markdown]
# ## Co-ocurrencia de apellidos para node2vec

# %%
# ---- DB Employees ---- 
freq = df_whole.groupby(["Paterno", "Materno"]).size()
freq
# Out:
# Paterno    Materno
# .          .             1
# AABY       HORMAZABAL    1
#            RIOS          1
# AAZCO      FUENTES       1
# ABACA      BENAVIDES     1
#                         ..
# ZWETAJEFF  MARCHANT      1
# ZWINGEL    RIO           2
# ZYCER      GROSSMAN      1
# ZYL        GONZALEZ      1
#            TORRES        1
# Length: 296578, dtype: int64

# %%
def get_freq_names(series):
    names = {}
    all_names = list(series.index)
    length = len(series)

    for i in range(0,length):

        name = all_names[i]
        paternal = name[0]
        maternal = name[1]
        value = series[i]

        if (paternal, maternal) in names:
            name[(paternal, maternal)] = name[(paternal, maternal)] + value
        elif (maternal, paternal) in names:
            names[(maternal, paternal)] = names[(maternal, paternal)] + value    
        elif (paternal, maternal) not in names:
            if (maternal, paternal) not in names:
                names[(paternal, maternal)] = value  
    
    df = pd.DataFrame(names.items(), columns=['names', 'n'])
    return df


get_freq_names(freq)
# Out:
#                       names  n
# 0           (ABADIE, RIVAS)  2
# 1       (ABARCA, CONTRERAS)  1
# 2          (ABARCA, WALLIS)  1
# 3          (ABARZUA, LILLO)  1
# 4         (ABARZUA, RIVERA)  1
# ...                     ... ..
# 7985      (ZUNIGA, URRIETA)  1
# 7986  (ZUNIGA, VALDEBENITO)  2
# 7987       (ZUNIGA, VARGAS)  1
# 7988    (ZUNIGA, VELASQUEZ)  1
# 7989       (ZUNIGA, ZUNIGA)  3
#
# [7990 rows x 2 columns]

# %%
regions = set(df_whole.region)

for region in regions:
    df_region = df_whole[df_whole.region == region]
    freq = df_region.groupby(["Paterno", "Materno"]).size()
    df_names = get_freq_names(freq)
    df_names.to_csv('data publica/apellidos/' + region + '.csv')

# %%
metro = df_whole[df_whole.region == 'Region Metropolitana de Santiago']
g_p = metro[(metro.Paterno == 'GONZALEZ') & (metro.Materno == 'PEREZ')]
p_g = metro[(metro.Paterno == 'PEREZ') & (metro.Materno == 'GONZALEZ')]

# %%
a= metro.groupby(["Paterno", "Materno"]).size()
alls = a.index
for i in range(len(a)):
    if alls[i][0] == 'GONZALEZ' and alls[i][1] == 'PEREZ':
        print(a[i])
    if alls[i][0] == 'PEREZ' and alls[i][1] == 'GONZALEZ':
        print(a[i])
# Out:
# 42
# 62

# %%
##AVG INCOME BY ORG
df_avg_orgs = df_whole.groupby(['organismo_codigo'])['remuneracionbruta_mensual'].mean()
df_avg_orgs.to_csv('resultados/avg_orgs.csv')

# %% [markdown]
# # Sample Entre Dos Personas

# %%
#df_pairs.to_csv('resultados/pares-sample-1000.csv')

# %%
from itertools import combinations
df_sample = df_whole.sample(n=10000, random_state=1)
df_sample = df_sample.reset_index()

# %%
df_sample = df_sample.drop('camino', 1)
df_sample = df_sample.drop('organismo_nombre', 1)
df_sample = df_sample.drop('anyo', 1)
df_sample = df_sample.drop('Mes', 1)
df_sample = df_sample.drop('Pago extra diurnas', 1)
df_sample = df_sample.drop('Pago extra nocturnas', 1)
df_sample = df_sample.drop('Pago extra festivas', 1)
df_sample = df_sample.drop('Horas extra diurnas', 1)
df_sample = df_sample.drop('Horas extra festivas', 1)
df_sample = df_sample.drop('Horas extra nocturnas', 1)
df_sample = df_sample.drop('observaciones', 1)
df_sample = df_sample.drop('enlace', 1)
df_sample = df_sample.drop('activado', 1)

df_sample
# Out:
#        index organismo_codigo fecha_publicacion            Nombres   Paterno  \
# 0     107693            CM051        2021/09/08      CESAR RICARDO    CASTRO
# 1     129211            MU332        2021/09/08      SUSANA ISABEL  BERRUETA
# 2     117059            MU237        2021/09/13       Luis Eduardo    Guiñez
# 3      89597            AD020        2021/09/14   GUILLERMO ANDRES    VARGAS
# 4      80469            AO055        2021/09/14     ROMINA ARLETTE   MELLADO
# ...      ...              ...               ...                ...       ...
# 9995   71600            AO069        2021/08/11  GERALDINE YAMILET    FLORES
# 9996    5144            CM051        2021/09/08  ANDREA DEL CARMEN   RAMIREZ
# 9997  135069            MU131        2021/09/11     VIVIANA ANDREA   BELTRÁN
# 9998  192215            AO081        2021/08/31   ROMINA STEPHANIE   CAMPAÑA
# 9999  194033            AO080        2021/08/19      TERESA PAMELA     RIVAS
#
#         Materno                                         Tipo cargo  \
# 0        ZUÑIGA  PARADOCENTE LICEO BICENTENARIO IGNACIO CARRERA...
# 1      DEL POZO               JEFATURA EN OF. DE ARCHIVO MUNICIPAL
# 2        Paiñel                                             CHOFER
# 3      GALLARDO                              OPERADOR AVSEC (H073)
# 4        FLORES                                            TÉCNICO
# ...         ...                                                ...
# 9995  CONTRERAS                                   ATENCION CLINICA
# 9996        RUZ  EDUCADORA DE PÁRVULOS ESCUELA CARMEN GALLEGOS ...
# 9997     MOLINA               PARADOCENTE ESCUELA F976  LA COLONIA
# 9998       VERA                                     ADMINISTRATIVO
# 9999     ALVIAL                              TECNICO DE ENFERMERIA
#
#                                  grado_eus  \
# 0     No Asimilado a Grado Jornada 44 Hrs.
# 1                                       10
# 2                     No Asimilado a Grado
# 3                                       13
# 4                                       21
# ...                                    ...
# 9995                                    24
# 9996  No Asimilado a Grado Jornada 44 Hrs.
# 9997                       Jornada 44 hrs.
# 9998                                    22
# 9999                                    22
#
#                                      tipo_calificacionp  \
# 0                         LICENCIADO DE ENSEÑANZA MEDIA
# 1                         INGENIERO EN ADM. DE EMPRESAS
# 2                                         Sin Profesion
# 3               ESPECIALISTA EN SEGURIDAD AEROPORTUARIA
# 4                                               TECNICO
# ...                                                 ...
# 9995                                   Atencion Clinica
# 9996                              EDUCADORA DE PARVULOS
# 9997                              INSPECTOR EDUCACIONAL
# 9998  INGENIERO (A) EJECUCION ADMINISTRACION DE RECU...
# 9999                                     TNS ENFERMERIA
#
#                                 region  ... Tipo Unidad monetaria  \
# 0                   Región de OHiggins  ...                 Pesos
# 1                 Región de Valparaíso  ...                 Pesos
# 2                   Región de OHiggins  ...                 Pesos
# 3     Región Metropolitana de Santiago  ...                 Pesos
# 4                Región de Antofagasta  ...                 Pesos
# ...                                ...  ...                   ...
# 9995  Región Metropolitana de Santiago  ...                 Pesos
# 9996                Región de OHiggins  ...                 Pesos
# 9997                 Región del Biobío  ...                 Pesos
# 9998  Región Metropolitana de Santiago  ...                 Pesos
# 9999  Región Metropolitana de Santiago  ...                 Pesos
#
#      remuneracionbruta_mensual  remuliquida_mensual  fecha_ingreso  \
# 0                    1102613.0             923679.0     01/03/2011
# 1                    1681739.0            1380229.0     19/08/1994
# 2                    1355193.0            1274737.0     12/09/1989
# 3                     717570.0             610348.0     01/08/2018
# 4                     479184.0                  NaN     01/01/2020
# ...                        ...                  ...            ...
# 9995                  515476.0                  NaN     01/01/2020
# 9996                 1453089.0            1124733.0     01/03/1995
# 9997                  381479.0             351625.0     06/03/2018
# 9998                  642507.0             480327.0     01/01/2020
# 9999                  630880.0                  NaN     01/01/2020
#
#      fecha_termino viaticos  Tipo Estamento descripcion_funcion  \
# 0       Indefinido      NaN             NaN                 NaN
# 1       Indefinido      0.0        Jefatura                 NaN
# 2       Indefinido      0.0        Auxiliar                 NaN
# 3       31/12/2020      NaN         Técnico                 NaN
# 4       24/05/2020      NaN         Técnico                 NaN
# ...            ...      ...             ...                 ...
# 9995    31/12/2020      NaN        Auxiliar                 NaN
# 9996    Indefinido      0.0         Docente                 NaN
# 9997    Indefinido      NaN             NaN                 NaN
# 9998    31/12/2020      NaN  Administrativo                 NaN
# 9999    31/12/2020      NaN         Técnico                 NaN
#
#      remuneracionbruta  pago_mensuales
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
# ...                ...             ...
# 9995               NaN             NaN
# 9996               NaN             NaN
# 9997               NaN             NaN
# 9998               NaN             NaN
# 9999               NaN             NaN
#
# [10000 rows x 21 columns]

# %%
pairs = list(combinations(df_sample.index,2))

# %%
# %%time
pd.DataFrame([pd.concat([df_sample.loc[pair[0],:],df_sample.loc[pair[1],:]]).reset_index(drop=True) for pair in pairs], index=pairs)

# %% [markdown]
# # Overview Interesante

# %% [markdown]
# ### Apellidos con mejores sueldos

# %%
#APELLIDOS CON FRECUENCIA MAYOR A N
n = 2
head = 30
target = df_whole[['Paterno','remuneracionbruta_mensual']].groupby(['Paterno']).agg(['mean', 'count'])
target2 = target.sort_values(by=[('remuneracionbruta_mensual', 'count')], ascending=False)['remuneracionbruta_mensual']

target3 = df_whole[['Materno','remuneracionbruta_mensual']].groupby(['Materno']).agg(['mean', 'count'])
target4 = target3.sort_values(by=[('remuneracionbruta_mensual', 'count')], ascending=False)['remuneracionbruta_mensual']
target4

renta_bruta = pd.merge(target2, target4,left_index=True, right_index=True, how='outer').fillna(0)
renta_bruta['Total'] = renta_bruta['count_x'] + renta_bruta['count_y']
renta_bruta['Renta bruta promedio'] = (renta_bruta['mean_x']*renta_bruta['count_x'] + renta_bruta['mean_y']*renta_bruta['count_y'])/(renta_bruta['count_x'] + renta_bruta['count_y'])

renta_bruta[['Renta bruta promedio','Total']].sort_values(by=['Renta bruta promedio'], ascending=False)[renta_bruta['Total'] > n].head(10)
# Out:
#                Renta bruta promedio  Total
# PERIBONIO              9,870,222.33   3.00
# PODUJE                 9,870,222.33   3.00
# ERRÁZURIZ              7,075,571.67   3.00
# APOSTOLIDIS            5,929,176.67   3.00
# VODANOVIC              5,822,392.25   4.00
# SIMPFENDORFER          5,707,397.67   3.00
# EXSS                   5,498,393.67   3.00
# FAINE                  5,346,564.20   5.00
# ZAMARIN                5,128,655.00   3.00
# REIMANN                5,057,576.67   3.00

# %% [markdown]
# ### Empleados por región

# %%
#Análisis por región
pd.options.display.float_format = '{:,.2f}'.format 
target = df_whole[['Nombres','region','remuneracionbruta_mensual']].groupby(['region']).agg(['mean', 'count'])
target2 = target.sort_values(by=[('remuneracionbruta_mensual', 'count')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2['%'] = target2['#']/target2['#'].sum()*100
target2
# Out:
#                                   Remuneración bruta promedio       #     %
# region
# Región Metropolitana de Santiago                 1,441,411.98  179374 31.39
# Región del Biobío                                1,181,084.95   61756 10.81
# Región de Valparaíso                             1,223,221.66   55957  9.79
# Región del Maule                                 1,132,534.95   43110  7.54
# Región de Los Lagos                              1,227,119.40   40597  7.10
# Región de La Araucanía                           1,214,597.32   34256  5.99
# Región de OHiggins                               1,175,055.69   32062  5.61
# Región de Coquimbo                               1,225,825.98   24347  4.26
# Región de Ñuble                                  1,147,053.87   20868  3.65
# Región de Antofagasta                            1,376,654.21   19965  3.49
# Región de Los Ríos                               1,303,124.35   14578  2.55
# Región de Atacama                                1,264,110.22   11530  2.02
# Región de Aysén                                  1,664,524.61    9110  1.59
# Región de Arica y Parinacota                     1,347,764.21    8852  1.55
# Región de Tarapacá                               1,531,068.66    7705  1.35
# Región de Magallanes                             1,708,802.90    7352  1.29

# %% [markdown]
# ### Áreas con mejor sueldo

# %%
#Areas y sueldos
n = 20
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)
target = pd.merge(df_whole, df_instituciones, left_on='organismo_codigo', right_on='Codigo_org', how='inner')
target2 = target[['Padre_org','remuliquida_mensual','remuneracionbruta_mensual']].groupby(['Padre_org']).agg(['mean', 'count'])
target2 = target2.sort_values(by=[('remuneracionbruta_mensual', 'mean')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2.head(20)
# Out:
#                                           Remuneración bruta promedio     #
# Padre_org
# Consejo Defensa del Estado                               4,171,632.90   600
# Consejo Fiscal Autónomo                                  3,266,666.67     3
# Ciencia Tecnología e Innovación                          2,947,180.72    67
# Empresas y Sociedades                                    2,883,969.14    22
# Hacienda                                                 2,876,360.61  5649
# Minería                                                  2,734,708.75   837
# Secretaría General de la Presidencia                     2,694,561.89   170
# Defensoría de los Derechos de la Niñez                   2,692,139.54    39
# Superintendencia de Servicios Sanitarios                 2,651,372.99   204
# Consejo para la Transparencia                            2,638,009.82   141
# Medio Ambiente                                           2,605,645.44  1164
# Energía                                                  2,510,590.72  1406
# La Mujer y Equidad de Género                             2,178,364.93   582
# Universidades                                            2,173,654.43   387
# Relaciones Exteriores                                    2,162,229.94   158
# Instituto Derechos Humanos                               2,140,556.87   194
# Bienes Nacionales                                        2,052,871.52   662
# Trabajo y Previsión Social                               2,013,108.57  7504
# Secretaría General de Gobierno                           2,011,442.42   544
# Economía Fomento y Turismo                               2,009,709.84  6009

# %% [markdown]
# ### Áreas con más empleados

# %%
pd.options.display.float_format = '{:,.2f}'.format
n = 20
target2 = target[['Padre_org','remuliquida_mensual','remuneracionbruta_mensual']].groupby(['Padre_org']).agg(['mean', 'count'])
target2 = target2.sort_values(by=[('remuneracionbruta_mensual', 'count')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2=target2.reindex(columns=['#','Remuneración bruta promedio']).head(n)
target2
# Out:
#                                                          #  \
# Padre_org
# Salud                                               172007
# Corporaciones Municipales                            55627
# Educación                                            45721
# Municipios de R. Metropolitana de Santiago           39663
# Municipios del Bíobio                                29603
# Municipios del Maule                                 28029
# Municipios de Los Lagos                              21297
# Municipios de Valparaíso                             19421
# Municipios de La Araucanía                           15811
# Municipios del Libertador General Bernardo OHig...   15602
# Municipios de Ñuble                                  14487
# Defensa Nacional                                     13168
# Justicia                                             12735
# Municipios de Coquimbo                               10881
# Obras Públicas                                        8658
# Trabajo y Previsión Social                            7504
# Municipios de Los Ríos                                6646
# Agricultura                                           6496
# Economía Fomento y Turismo                            6009
# Hacienda                                              5649
#
#                                                     Remuneración bruta promedio
# Padre_org
# Salud                                                              1,368,032.37
# Corporaciones Municipales                                          1,255,989.16
# Educación                                                          1,028,344.65
# Municipios de R. Metropolitana de Santiago                         1,189,902.89
# Municipios del Bíobio                                              1,053,166.34
# Municipios del Maule                                               1,053,480.66
# Municipios de Los Lagos                                            1,029,377.66
# Municipios de Valparaíso                                           1,084,215.05
# Municipios de La Araucanía                                         1,070,398.44
# Municipios del Libertador General Bernardo OHig...                 1,065,340.90
# Municipios de Ñuble                                                1,012,115.20
# Defensa Nacional                                                   1,320,380.43
# Justicia                                                           1,691,173.64
# Municipios de Coquimbo                                             1,147,735.42
# Obras Públicas                                                     1,671,330.73
# Trabajo y Previsión Social                                         2,013,108.57
# Municipios de Los Ríos                                             1,097,368.78
# Agricultura                                                        1,745,178.61
# Economía Fomento y Turismo                                         2,009,709.84
# Hacienda                                                           2,876,360.61

# %% [markdown]
# ### Organismos con mejor sueldo

# %%
n = 20
target2 = target[['Organismo','remuliquida_mensual','remuneracionbruta_mensual']].groupby(['Organismo']).agg(['mean', 'count'])
target2 = target2.sort_values(by=[('remuneracionbruta_mensual', 'mean')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2.head(20)
# Out:
#                                                     Remuneración bruta promedio  \
# Organismo
# Consejo de Defensa del Estado (CDE)                                4,171,632.90
# Agencia de Promoción de la Inversión Extranjera                    4,044,715.67
# Comisión Nacional de Energía (CNE)                                 3,951,162.79
# Servicio Local de Educación Pública Colchagua                      3,911,584.25
# Dirección de Presupuestos (DIPRES)                                 3,852,747.80
# Comisión para el Mercado Financiero (CMF  ex SVS)                  3,785,813.67
# Fiscalía Nacional Económica (FNE)                                  3,754,238.99
# Dirección Nacional del Servicio Civil                              3,739,104.43
# Superintendencia de Casinos de Juego (SCJ)                         3,645,589.56
# Comisión Chilena del Cobre (COCHILCO)                              3,554,871.93
# Subsecretaría de Turismo                                           3,372,740.72
# Defensoría Penal Pública (DPP)                                     3,328,802.71
# Administradora de los Tribunales Tributarios y ...                 3,322,826.81
# Consejo Fiscal Autónomo                                            3,266,666.67
# Superintendencia de Pensiones (SP)                                 3,236,942.89
# Unidad de Análisis Financiero                                      3,211,291.99
# Junta de Aeronáutica Civil (JAC)                                   3,154,120.65
# Universidad de Aysén                                               3,128,747.05
# Dirección General de Concesiones de Obras Públi...                 2,978,955.30
# Superintendencia del Medio Ambiente (SMA)                          2,950,105.92
#
#                                                       #
# Organismo
# Consejo de Defensa del Estado (CDE)                 600
# Agencia de Promoción de la Inversión Extranjera      54
# Comisión Nacional de Energía (CNE)                  102
# Servicio Local de Educación Pública Colchagua         4
# Dirección de Presupuestos (DIPRES)                  372
# Comisión para el Mercado Financiero (CMF  ex SVS)   657
# Fiscalía Nacional Económica (FNE)                   117
# Dirección Nacional del Servicio Civil               156
# Superintendencia de Casinos de Juego (SCJ)           59
# Comisión Chilena del Cobre (COCHILCO)                96
# Subsecretaría de Turismo                             25
# Defensoría Penal Pública (DPP)                      763
# Administradora de los Tribunales Tributarios y ...   42
# Consejo Fiscal Autónomo                               3
# Superintendencia de Pensiones (SP)                  255
# Unidad de Análisis Financiero                        70
# Junta de Aeronáutica Civil (JAC)                     23
# Universidad de Aysén                                 93
# Dirección General de Concesiones de Obras Públi...  261
# Superintendencia del Medio Ambiente (SMA)           264

# %% [markdown]
# ### Estamentos con mejores sueldos

# %%
n = 20
target2 = target[['Tipo Estamento','remuliquida_mensual','remuneracionbruta_mensual']].groupby(['Tipo Estamento']).agg(['mean', 'count'])
target2 = target2.sort_values(by=[('remuneracionbruta_mensual', 'mean')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2.head(20)
# Out:
#                                                     Remuneración bruta promedio  \
# Tipo Estamento
# Autoridad de Gobierno                                              8,675,225.90
# Jefe Superior de Servicio                                          8,009,793.64
# Alcalde                                                            5,263,097.02
# Directivo                                                          3,628,557.60
# Experto                                                            2,717,976.32
# Médicos cirujanos farmacéuticos químicofarmacéu...                 2,664,261.79
# Cargo en Extinción                                                 2,662,422.27
# Fiscalizador                                                       2,363,203.87
# Docentedirectivo                                                   2,065,250.13
# Otros profesionales (Ley 19.378)                                   1,994,722.13
# Profesional                                                        1,964,164.72
# Jefatura                                                           1,751,884.52
# Técnicopedagógico                                                  1,711,623.23
# Sin Estamento                                                      1,511,055.90
# Auxiliar Paramédico                                                1,252,818.81
# Docente                                                            1,232,733.70
# Técnicos de nivel superior (Ley 19.378)                            1,134,259.13
# Técnicos de Salud                                                  1,100,272.03
# Educación                                                          1,082,572.86
# Administrativos de Salud                                             982,206.49
#
#                                                          #
# Tipo Estamento
# Autoridad de Gobierno                                   48
# Jefe Superior de Servicio                               28
# Alcalde                                                250
# Directivo                                             6173
# Experto                                                 59
# Médicos cirujanos farmacéuticos químicofarmacéu...   38327
# Cargo en Extinción                                      11
# Fiscalizador                                          2658
# Docentedirectivo                                      2951
# Otros profesionales (Ley 19.378)                     13563
# Profesional                                         113640
# Jefatura                                              1594
# Técnicopedagógico                                     1340
# Sin Estamento                                          742
# Auxiliar Paramédico                                    253
# Docente                                              77618
# Técnicos de nivel superior (Ley 19.378)              13907
# Técnicos de Salud                                     2515
# Educación                                             1680
# Administrativos de Salud                              4757

# %% [markdown]
# ### Estamentos más grandes

# %%
n=20
pd.options.display.float_format = '{:,.2f}'.format
target2 = target[['Tipo Estamento','remuliquida_mensual','remuneracionbruta_mensual']].groupby(['Tipo Estamento']).agg(['mean', 'count'])
target2 = target2.sort_values(by=[('remuneracionbruta_mensual', 'count')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2=target2.reindex(columns=['#','Remuneración bruta promedio'])
target2.head(n)
# Out:
#                                                          #  \
# Tipo Estamento
# Profesional                                         113640
# Técnico                                              84343
# Docente                                              77618
# Administrativo                                       50656
# Médicos cirujanos farmacéuticos químicofarmacéu...   38327
# Auxiliar                                             34404
# Técnicos de nivel superior (Ley 19.378)              13907
# Otros profesionales (Ley 19.378)                     13563
# Directivo                                             6173
# Auxiliares de servicios de Salud                      5115
# Administrativos de Salud                              4757
# Docentedirectivo                                      2951
# Fiscalizador                                          2658
# Técnicos de Salud                                     2515
# Educación                                             1680
# Jefatura                                              1594
# No docente de servicios auxiliares                    1437
# Técnicopedagógico                                     1340
# No docente paradocente                                1175
# Chofer                                                 782
#
#                                                     Remuneración bruta promedio
# Tipo Estamento
# Profesional                                                        1,964,164.72
# Técnico                                                              830,707.02
# Docente                                                            1,232,733.70
# Administrativo                                                       856,961.30
# Médicos cirujanos farmacéuticos químicofarmacéu...                 2,664,261.79
# Auxiliar                                                             691,469.11
# Técnicos de nivel superior (Ley 19.378)                            1,134,259.13
# Otros profesionales (Ley 19.378)                                   1,994,722.13
# Directivo                                                          3,628,557.60
# Auxiliares de servicios de Salud                                     877,448.19
# Administrativos de Salud                                             982,206.49
# Docentedirectivo                                                   2,065,250.13
# Fiscalizador                                                       2,363,203.87
# Técnicos de Salud                                                  1,100,272.03
# Educación                                                          1,082,572.86
# Jefatura                                                           1,751,884.52
# No docente de servicios auxiliares                                   508,845.54
# Técnicopedagógico                                                  1,711,623.23
# No docente paradocente                                               553,923.52
# Chofer                                                               871,901.62

# %% [markdown]
# ### Organismos con más empleados

# %%
n=20
pd.options.display.float_format = '{:,.2f}'.format
target2 = target[['Organismo','remuliquida_mensual','remuneracionbruta_mensual']].groupby(['Organismo']).agg(['mean', 'count'])
target2 = target2.sort_values(by=[('remuneracionbruta_mensual', 'count')], ascending=False)['remuneracionbruta_mensual']
target2.columns = ['Remuneración bruta promedio', '#']
target2=target2.reindex(columns=['#','Remuneración bruta promedio'])
target2.head(n)
# Out:
#                                                         #  \
# Organismo
# Junta Nacional de Jardines Infantiles (JUNJI)       20054
# Municipalidad de Puerto Montt                        8935
# Municipalidad de Santiago                            6612
# Municipalidad de Talca                               6378
# Corporación Municipal de Desarrollo Social de A...   5816
# Corporación Municipal de Valparaíso                  5321
# Dirección de Vialidad (VIALIDAD)                     5021
# Hospital Sótero del Río                              4983
# Hospital Guillermo Grant Benavente de Concepción     4950
# Servicio de Salud Metropolitano Sur Oriente          4948
# Servicio Nacional de Menores (SENAME)                4752
# Dirección General de Aeronáutica Civil (DGAC)        4706
# Corporación Municipal de San Bernardo                4633
# Corporación Municipal de Puente Alto                 4609
# Servicio Agrícola y Ganadero (SAG)                   4326
# Municipalidad de Chillán                             4324
# Hospital Dr. Hernán Henríquez Aravena de Temuco      4160
# Municipalidad de Curicó                              3962
# Municipalidad de Talcahuano                          3902
# Municipalidad de Osorno                              3785
#
#                                                     Remuneración bruta promedio
# Organismo
# Junta Nacional de Jardines Infantiles (JUNJI)                        742,060.55
# Municipalidad de Puerto Montt                                        762,782.21
# Municipalidad de Santiago                                          1,309,185.46
# Municipalidad de Talca                                             1,148,998.31
# Corporación Municipal de Desarrollo Social de A...                 1,395,650.72
# Corporación Municipal de Valparaíso                                1,095,165.26
# Dirección de Vialidad (VIALIDAD)                                   1,391,283.77
# Hospital Sótero del Río                                            1,353,696.43
# Hospital Guillermo Grant Benavente de Concepción                   1,281,762.86
# Servicio de Salud Metropolitano Sur Oriente                        1,266,378.67
# Servicio Nacional de Menores (SENAME)                              1,595,693.12
# Dirección General de Aeronáutica Civil (DGAC)                      1,624,211.95
# Corporación Municipal de San Bernardo                              1,185,460.43
# Corporación Municipal de Puente Alto                               1,281,128.48
# Servicio Agrícola y Ganadero (SAG)                                 1,558,336.23
# Municipalidad de Chillán                                             870,787.13
# Hospital Dr. Hernán Henríquez Aravena de Temuco                    1,178,617.18
# Municipalidad de Curicó                                            1,083,400.38
# Municipalidad de Talcahuano                                        1,047,547.80
# Municipalidad de Osorno                                            1,346,694.79
