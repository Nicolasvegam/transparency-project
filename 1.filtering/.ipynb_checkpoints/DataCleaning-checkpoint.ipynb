# %% [markdown]
# # Limpieza Datos de Transparencia

# %% [markdown]
# \[CONTEXT\] La información a disposición en el portal de transparencia (https://www.portaltransparencia.cl/PortalPdT/web/guest/home) está en un formato dot csv. Los archivos son de tamaño 1GB a 4GB, ya que trae la data histórica desde los años 2016-2017. Los datos son sobre la composición de trabajadores en los distintos tipos de contrato.
#
# \[PROBLEM\] El tamaño de estos archivos (6-12 millones de filas, i.e, 1-4GB) son muy pesados como para ser tratados como frames. Por ende, se deben filtrar para tomar la data de interés (un punto determinado del tiempo, i.e, un mes y un año en particular).
#
# \[SOLUTION\] Usaremos la librería "dask", que usa multiprocesamiento en paralelo y que nos ayudará a filtrar esta data. El resultado serán archivos de 4KB (10^6 más pequeños que los archivos originales).

# %%
#Import dask
import dask.dataframe as dd

# %%
#Specify year and month
year = 2020
month = 'Abril'

# %% [markdown]
# ### \[READ\] Personal Código del Trabajo

# %%
#Path to file
PATH = '../0.data/TA_PersonalCodigotrabajo.csv'

#Specify metatype to faster analysis
types = {'camino': str, 'organismo_nombre': str, 'organismo_codigo': str, 'fecha_publicacion': str,
       'anyo': str, 'Mes': str, 'nombre': str, 'Tipo cargo': str, 'grado_eus': str,
       'tipo_calificacionp': str, 'region': str, 'asignaciones': str, 'Tipo Unidad monetaria': str,
       'remuneracionbruta_mensual': float, 'remuliquida_mensual': float, 'diurnas': str,
       'nocturnas': str, 'fecha_ingreso': str, 'fecha_termino': str, 'observaciones': str,
       'viaticos': str, 'enlace': str}

#Read
df = dd.read_csv(PATH, encoding='ISO-8859-1', delimiter=';', dtype = types)

#Display first rows
df.head()
# Out:
#             camino                                   organismo_nombre  \
# 0  /Año 2017/Enero                            Municipalidad de Vicuña
# 1  /Año 2017/Enero                            Municipalidad de Vicuña
# 2  /Año 2018/Abril  Asociación de Municipalidades Territorio de Ri...
# 3    /2018/Febrero  Ex Consejo Nacional de la Cultura y las Artes ...
# 4    /2018/Febrero  Ex Consejo Nacional de la Cultura y las Artes ...
#
#   organismo_codigo fecha_publicacion  anyo      Mes     Nombres  Paterno  \
# 0            MU335        2017/03/09  2017    Enero     Nicolás   Puebla
# 1            MU335        2017/03/09  2017    Enero       César   Puebla
# 2            MA011        2021/01/13  2018    Abril  Gina Maria  Hidalgo
# 3            AV001        2018/05/15  2018  Febrero       KARLA    GAETE
# 4            AV001        2018/05/15  2018  Febrero       JORGE  GAJARDO
#
#     Materno            Tipo cargo  ... Horas extra diurnas  \
# 0  Gallardo               RELATOR  ...                 NaN
# 1      Ruíz              Analista  ...                 NaN
# 2   Cancino  Secretaria Ejecutiva  ...                 NaN
# 3     SILVA     PRIMERA BAILARINA  ...                 NaN
# 4   BEROIZA         PRIMER MUSICO  ...                 NaN
#
#   Pago extra nocturnas Horas extra nocturnas Pago extra festivas  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Horas extra festivas  fecha_ingreso  fecha_termino      observaciones  \
# 0                  NaN     01/01/2017     01/12/2017  Sin observaciones
# 1                  NaN     01/01/2017     31/12/2017  Sin observaciones
# 2                  NaN     16/04/2018     Indefinido  Sin observaciones
# 3                  NaN     01/01/2006     Indefinido  Sin observaciones
# 4                  NaN     01/01/2007     Indefinido  Sin observaciones
#
#    viaticos                                             enlace
# 0       NaN  a href=http:www.google.com target=_blankwww.go...
# 1       NaN                                                 No
# 2       NaN                                                 No
# 3       NaN                                                 No
# 4       NaN                                                 No
#
# [5 rows x 28 columns]

# %% [markdown]
# ### \[FILTERING\] Personal Código del Trabajo

# %%
#Filtering original frame
new_df = df[df.anyo == str(year)]
new_df = new_df[new_df.Mes == month]

#Save new frame
new_df.to_csv('../2.filtered-data/' + month + str(year) + 'PersonalCodigotrabajo.csv', single_file = True)

#Display head
new_df.head()
# Out:
#                 camino                                   organismo_nombre  \
# 33851  /Año 2020/Abril                Asociación de Municipios Ciudad Sur
# 33852  /Año 2020/Abril                Asociación de Municipios Ciudad Sur
# 33974      /2020/Abril  Asociación Chilena de Municipalidades con Farm...
# 33975      /2020/Abril  Asociación Chilena de Municipalidades con Farm...
# 33976      /2020/Abril  Asociación Chilena de Municipalidades con Farm...
#
#       organismo_codigo fecha_publicacion  anyo    Mes           Nombres  \
# 33851            MA031        2020/12/03  2020  Abril               Ana
# 33852            MA031        2020/12/03  2020  Abril              José
# 33974            MA053        2020/08/11  2020  Abril    Pablo Salvador
# 33975            MA053        2020/08/11  2020  Abril  Ricardo Mauricio
# 33976            MA053        2020/08/11  2020  Abril         Ana María
#
#          Paterno   Materno                                         Tipo cargo  \
# 33851  Montrosis     Guaje                                     ADMINISTRATIVA
# 33852       Soto  Sandoval  SECRETARIO EJECUTIVO CIUDAD SUR  ENCARGADO REL...
# 33974     Zúñiga  Jorquera                           PROYECTOS Y COMUNICACIÓN
# 33975     Santis    Zuñiga                               LABORATORIO AUDITIVO
# 33976    Pineida  Olivares                           ASISTENTE ADMINISTRATIVA
#
#        ... Horas extra diurnas Pago extra nocturnas Horas extra nocturnas  \
# 33851  ...                 NaN                  NaN                   NaN
# 33852  ...                 NaN                  NaN                   NaN
# 33974  ...                 NaN                  NaN                   NaN
# 33975  ...                 NaN                  NaN                   NaN
# 33976  ...                 NaN                  NaN                   NaN
#
#       Pago extra festivas Horas extra festivas  fecha_ingreso  fecha_termino  \
# 33851                 NaN                  NaN     01/12/2018     31/12/2020
# 33852                 NaN                  NaN     01/08/2018     31/12/2020
# 33974                 NaN                  NaN     01/04/2018     Indefinido
# 33975                 NaN                  NaN     01/08/2019     Indefinido
# 33976                 NaN                  NaN     01/01/2018     Indefinido
#
#            observaciones  viaticos  enlace
# 33851  Sin observaciones       NaN      No
# 33852  Sin observaciones       NaN      No
# 33974  Sin observaciones       NaN      No
# 33975  Sin observaciones       NaN      No
# 33976  Sin observaciones       NaN      No
#
# [5 rows x 28 columns]

# %% [markdown]
# ### \[READ\] Personal Contrata

# %%
#Path to file
PATH = '../0.data/TA_PersonalContrata.csv'

#Specify metadata for faster reading
types = {'camino': str, 'organismo_nombre': str, 'organismo_codigo': str, 'fecha_publicacion': str,
       'anyo': str, 'Mes': str, 'Tipo Estamento': str, 'nombre': str, 'Tipo cargo': str, 'grado_eus': str,
       'tipo_calificacionp': str, 'region': str, 'asignaciones': str, 'Tipo Unidad monetaria': str,
       'remuneracionbruta_mensual': float, 'remuliquida_mensual': float, 'diurnas': str, 'festivas':str,
       'nocturnas': str, 'fecha_ingreso': str, 'fecha_termino': str, 'observaciones': str,
       'viaticos': str, 'enlace': str, 'Pago extra diurnas': 'float64'}

#Read
df2 = dd.read_csv(PATH, encoding='ISO-8859-1', delimiter=';', dtype=types)

#Display first rows
df2.head()
# Out:
#       camino    organismo_nombre organismo_codigo fecha_publicacion  anyo  \
# 0  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 1  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 2  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 3  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
# 4  /Pagina 3  Partido Ciudadanos            PP030        2016/06/29  2016
#
#      Mes  Tipo Estamento             Nombres     Paterno    Materno  ...  \
# 0  Abril     Profesional       JORGE ANTONIO     CARRIZO   CARRASCO  ...
# 1  Abril     Profesional       HOMERO ANDRES     CASANGA     CORTES  ...
# 2  Abril     Profesional       TOMAS RODRIGO  CASAREGGIO  SEPULVEDA  ...
# 3  Abril  Administrativo  SEBASTIAN ABELARDO    CASTILLO  SEPULVEDA  ...
# 4  Abril     Profesional        AIDA MORELIA      CASTRO     CASTRO  ...
#
#   Horas extra diurnas Pago extra nocturnas Horas extra nocturnas  \
# 0                 8.0                  NaN                   NaN
# 1                 8.0                  NaN                   NaN
# 2                 8.0                  NaN                   NaN
# 3                 8.0                  NaN                   NaN
# 4                 8.0                  NaN                   NaN
#
#   Pago extra festivas Horas extra festivas fecha_ingreso  fecha_termino  \
# 0                 NaN                  NaN    15/06/2011     16/04/2015
# 1                 NaN                  NaN    16/06/2011     17/04/2015
# 2                 NaN                  NaN    17/06/2011     18/04/2015
# 3                 NaN                  NaN    18/06/2011     19/04/2015
# 4                 NaN                  NaN    19/06/2011     20/04/2015
#
#                       observaciones  enlace  viaticos
# 0  Esto es un funcionario de prueba      No       NaN
# 1  Esto es un funcionario de prueba      No       NaN
# 2  Esto es un funcionario de prueba      No       NaN
# 3  Esto es un funcionario de prueba      No       NaN
# 4  Esto es un funcionario de prueba      No       NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### \[FILTERING\] Personal Contrata

# %%
#Filter original frame 
new_df2 = df2[df2.anyo == str(year)]
new_df2 = new_df2[new_df2.Mes == month]

#Save new frame
new_df2.to_csv('../2.filtered-data/' + month + str(year) + 'PersonalContrata.csv', single_file = True)

#Display first rows
new_df2.head()
# Out:
#                                  camino             organismo_nombre  \
# 23022  /Municipalidad/2020/Mes de Abril  Municipalidad de Llanquihue
# 23023  /Municipalidad/2020/Mes de Abril  Municipalidad de Llanquihue
# 23024  /Municipalidad/2020/Mes de Abril  Municipalidad de Llanquihue
# 23025  /Municipalidad/2020/Mes de Abril  Municipalidad de Llanquihue
# 23026  /Municipalidad/2020/Mes de Abril  Municipalidad de Llanquihue
#
#       organismo_codigo fecha_publicacion  anyo    Mes  Tipo Estamento  \
# 23022            MU142        2020/10/30  2020  Abril         Técnico
# 23023            MU142        2020/10/30  2020  Abril        Auxiliar
# 23024            MU142        2020/10/30  2020  Abril  Administrativo
# 23025            MU142        2020/10/30  2020  Abril        Auxiliar
# 23026            MU142        2020/10/30  2020  Abril  Administrativo
#
#                  Nombres    Paterno   Materno  ... Horas extra diurnas  \
# 23022     RODRIGO ANDRES  BAHAMONDE   TENORIO  ...                40.0
# 23023   MAURICIO ROLANDO   ALVARADO  GONZALEZ  ...                 1.0
# 23024     RAÚL ALEJANDRO  BAHAMONDE   TENORIO  ...                 3.0
# 23025  HERIBERTO SEGUNDO     AGUERO    VARGAS  ...                32.0
# 23026   MARCIA ALEJANDRA    ANDRADE     PINOL  ...                 1.0
#
#       Pago extra nocturnas Horas extra nocturnas Pago extra festivas  \
# 23022             229676.0                  40.0                 0.0
# 23023                  0.0                   0.0                 0.0
# 23024                  0.0                   0.0                 0.0
# 23025             211316.0                  72.0                 0.0
# 23026                  0.0                   0.0                 0.0
#
#       Horas extra festivas fecha_ingreso  fecha_termino      observaciones  \
# 23022                  0.0    01/02/2017     31/12/2020  Sin observaciones
# 23023                  0.0    01/05/2017     31/12/2020  Sin observaciones
# 23024                  0.0    13/10/2015     31/12/2020  Sin observaciones
# 23025                  0.0    01/01/2015     31/12/2020  Sin observaciones
# 23026                  0.0    01/03/2016     31/12/2020  Sin observaciones
#
#        enlace  viaticos
# 23022      No       NaN
# 23023      No       NaN
# 23024      No       NaN
# 23025      No       NaN
# 23026      No       NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### ### \[READ\] Personal de Planta

# %%
#Path to file
PATH = '../0.data/TA_PersonalPlanta.csv'

#Specify metadata for faster reading
types = {'camino': str, 'organismo_nombre': str, 'organismo_codigo': str, 'fecha_publicacion': str,
       'anyo': str, 'Mes': str, 'Tipo Estamento': str, 'nombre': str, 'Tipo cargo': str, 'grado_eus': str,
       'tipo_calificacionp': str, 'region': str, 'asignaciones': str, 'Tipo Unidad monetaria': str,
       'remuneracionbruta_mensual': float, 'remuliquida_mensual': float, 'diurnas': str, 'festivas':str,
       'nocturnas': str, 'fecha_ingreso': str, 'fecha_termino': str, 'observaciones': str,
       'viaticos': str, 'enlace': str}

#Read
df3 = dd.read_csv(PATH, encoding='ISO-8859-1', delimiter=';', dtype = types)

#Display first rows
df3.head()
# Out:
#                                      camino             organismo_nombre  \
# 0  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 1  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 2  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 3  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
# 4  /Municipal/Municipal Año 2014/Septiembre  Municipalidad de Puchuncaví
#
#   organismo_codigo fecha_publicacion  anyo    Mes  Tipo Estamento  \
# 0            MU229        2015/02/27  2014  Julio  Administrativo
# 1            MU229        2015/02/27  2014  Julio  Administrativo
# 2            MU229        2015/02/27  2014  Julio        Auxiliar
# 3            MU229        2015/02/27  2014  Julio        Jefatura
# 4            MU229        2015/02/27  2014  Julio         Técnico
#
#               Nombres   Paterno Materno  ... Horas extra diurnas  \
# 0  ANDREA DEL ROSARIO   ARAVENA   MUÑOZ  ...                 NaN
# 1        JOSE ANTONIO     ARAYA   ROJAS  ...                 NaN
# 2              MANUEL     ARAYA   ROJAS  ...                 NaN
# 3   MIRIAM DEL CARMEN      ARCE  MORENO  ...                 NaN
# 4        LUIS ANTONIO  ARELLANO    SOZA  ...                 NaN
#
#   Pago extra nocturnas Horas extra nocturnas Pago extra festivas  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   Horas extra festivas fecha_ingreso  fecha_termino      observaciones  \
# 0                  NaN    10/06/1996     Indefinido  SIN OBSERVACIONES
# 1                  NaN    01/09/1986     Indefinido  SIN OBSERVACIONES
# 2                  NaN    01/11/1987     Indefinido  SIN OBSERVACIONES
# 3                  NaN    16/12/1991     Indefinido  SIN OBSERVACIONES
# 4                  NaN    01/11/1967     Indefinido  SIN OBSERVACIONES
#
#    enlace  viaticos
# 0      No       0.0
# 1      No       0.0
# 2      No       0.0
# 3      No       0.0
# 4      No       0.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### \[FILTERING\] Personal de Planta

# %%
#Filter original frame
new_df3 = df3[df3.anyo == str(year)]
new_df3 = new_df3[new_df3.Mes == month]

#Save new frame
new_df3.to_csv('../2.filtered-data/' + month + str(year) + 'PersonalPlanta.csv', single_file = True)

#Display first rows
new_df3.head()
# Out:
#                                                camino  \
# 13716  /Municipalidad de Llanquihue/2020/Mes de Abril
# 13717  /Municipalidad de Llanquihue/2020/Mes de Abril
# 13718  /Municipalidad de Llanquihue/2020/Mes de Abril
# 13719  /Municipalidad de Llanquihue/2020/Mes de Abril
# 13720  /Municipalidad de Llanquihue/2020/Mes de Abril
#
#                   organismo_nombre organismo_codigo fecha_publicacion  anyo  \
# 13716  Municipalidad de Llanquihue            MU142        2020/10/30  2020
# 13717  Municipalidad de Llanquihue            MU142        2020/10/30  2020
# 13718  Municipalidad de Llanquihue            MU142        2020/10/30  2020
# 13719  Municipalidad de Llanquihue            MU142        2020/10/30  2020
# 13720  Municipalidad de Llanquihue            MU142        2020/10/30  2020
#
#          Mes  Tipo Estamento            Nombres  Paterno   Materno  ...  \
# 13716  Abril  Administrativo     MARIA ANGELICA    REYES     LEIVA  ...
# 13717  Abril  Administrativo     VICTOR EUGENIO    REYES    ROMERO  ...
# 13718  Abril        Auxiliar    YOCELYN VIVIANA    ROGEL   LEVICAN  ...
# 13719  Abril  Administrativo     NATALIA ANDREA     SAEZ  CARRILLO  ...
# 13720  Abril        Auxiliar  FRANCISCO ROLANDO  SANCHEZ  GONZALEZ  ...
#
#       Horas extra diurnas Pago extra nocturnas Horas extra nocturnas  \
# 13716                11.0                  0.0                   0.0
# 13717                 0.0              21089.0                   6.0
# 13718                 0.0                  0.0                   0.0
# 13719                 7.0                  0.0                   0.0
# 13720                 6.0                  0.0                   0.0
#
#       Pago extra festivas Horas extra festivas fecha_ingreso  fecha_termino  \
# 13716                 0.0                  0.0    01/01/2015     Indefinido
# 13717                 0.0                  0.0    01/04/2000     Indefinido
# 13718                 0.0                  0.0    01/06/2016     Indefinido
# 13719                 0.0                  0.0    03/06/2019     Indefinido
# 13720                 0.0                  0.0    01/01/2015     Indefinido
#
#            observaciones  enlace  viaticos
# 13716  Sin observaciones      No       0.0
# 13717  Sin observaciones      No       0.0
# 13718  Sin observaciones      No       0.0
# 13719  Sin observaciones      No       0.0
# 13720  Sin observaciones      No       0.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### \[READ\] Personal Contratada a Honorario

# %%
#Path to file
PATH = '../0.data/TA_PersonalContratohonorarios.csv'

#Specify metadata to faster reading
types = {'camino': str, 'organismo_nombre': str, 'organismo_codigo': str, 'fecha_publicacion': str,
       'anyo': str, 'Mes': str, 'nombre': str, 'grado_eus': str, 'descripcion_funcion': str,
       'tipo_calificacionp': str, 'region': str, 'Tipo Unidad monetaria': str,
       'remuneracionbruta': float, 'remuliquida_mensual': float, 'pago_mensuales': str, 
       'fecha_ingreso': str, 'fecha_termino': str, 'observaciones': str,
       'viaticos': str, 'enlace': str}

#Read
df4 = dd.read_csv(PATH, encoding='ISO-8859-1', delimiter=';')

#Display first rows
df4.head()
# Out:
#              camino                                   organismo_nombre  \
# 0    /Año 2017/Mayo  Asociación de Municipalidades del Valle del Maipo
# 1   /Año 2017/Junio  Asociación de Municipalidades del Valle del Maipo
# 2   /Año 2017/Julio  Asociación de Municipalidades del Valle del Maipo
# 3  /Año 2017/Agosto  Asociación de Municipalidades del Valle del Maipo
# 4   /2017/Noviembre  Asociación Municipalidades Provincia de Llanqu...
#
#   organismo_codigo fecha_publicacion  anyo        Mes           Nombres  \
# 0            MA049        2020/12/01  2017      Junio              Luis
# 1            MA049        2020/12/01  2017      Junio              Luis
# 2            MA049        2020/12/01  2017      Junio              Luis
# 3            MA049        2020/12/01  2017      Junio              Luis
# 4            MA025        2017/12/21  2017  Noviembre  Alejandro Javier
#
#     Paterno    Materno             grado_eus  ...  \
# 0  Céspedes  Inostroza  No asimilado a Grado  ...
# 1  Céspedes  Inostroza  No asimilado a Grado  ...
# 2  Céspedes  Inostroza  No asimilado a Grado  ...
# 3  Céspedes  Inostroza  No asimilado a Grado  ...
# 4   Bórquez     Felmer  No asimilado a grado  ...
#
#                              region Tipo Unidad monetaria remuneracionbruta  \
# 0  Región Metropolitana de Santiago                 Pesos            888889
# 1  Región Metropolitana de Santiago                 Pesos            888889
# 2  Región Metropolitana de Santiago                 Pesos            888889
# 3  Región Metropolitana de Santiago                 Pesos            888889
# 4               Región de Los Lagos                 Pesos           1700000
#
#   remuliquida_mensual  pago_mensuales            fecha_ingreso fecha_termino  \
# 0            800000.0              Sí  2016/06/01 00:00:00.000    31/12/2017
# 1            800000.0              Sí  2016/06/01 00:00:00.000    31/12/2017
# 2            800000.0              Sí  2016/06/01 00:00:00.000    31/12/2017
# 3            800000.0              Sí  2016/06/01 00:00:00.000    31/12/2017
# 4           1530000.0              Sí  2016/12/01 00:00:00.000    31/12/2017
#
#        observaciones enlace viaticos
# 0  Sin observaciones     No      NaN
# 1  Sin observaciones     No      NaN
# 2  Sin observaciones     No      NaN
# 3  Sin observaciones     No      NaN
# 4  Sin observaciones     No      NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### \[FILTERING\] Personal Contratada a Honorario

# %%
#Filter original frame
new_df4 = df4[df4.anyo == year]
new_df4 = new_df4[new_df4.Mes == month]

#Save new frame
new_df4.to_csv('../2.filtered-data/' + month + str(year) + 'PersonalHonorarios.csv', single_file = True)

#Display first rows
new_df4.head()
# Out:
#                                                   camino  \
# 50056  /Contrato a Honorarios Municipalidad 21.04 (su...
# 65149                    /Municipal/Municipal 2020/Abril
# 65150                    /Municipal/Municipal 2020/Abril
# 65151                    /Municipal/Municipal 2020/Abril
# 65152                    /Municipal/Municipal 2020/Abril
#
#                    organismo_nombre organismo_codigo fecha_publicacion  anyo  \
# 50056  Municipalidad de Los Angeles            MU153        2020/03/13  2020
# 65149    Municipalidad de Melipilla            MU173        2020/12/15  2020
# 65150    Municipalidad de Melipilla            MU173        2020/12/15  2020
# 65151    Municipalidad de Melipilla            MU173        2020/12/15  2020
# 65152    Municipalidad de Melipilla            MU173        2020/12/15  2020
#
#          Mes            Nombres     Paterno   Materno             grado_eus  \
# 50056  Abril     WILLIAMS YERKO    AGUILERA  CARDENAS  No asimilado a Grado
# 65149  Abril  GUSTAVO ALEJANDRO      GUZMAN   CANALES  No Asimilado a Grado
# 65150  Abril      ROMINA ANDREA    VALDIVIA    MESINA  No Asimilado a Grado
# 65151  Abril       JOSE ANTONIO    VALDIVIA      VERA  No Asimilado a Grado
# 65152  Abril     FLORENCIO JOSE  VALDOVINOS     REYES  No Asimilado a Grado
#
#        ...                            region Tipo Unidad monetaria  \
# 50056  ...                 Región del Biobío                 Pesos
# 65149  ...  Región Metropolitana de Santiago                 Pesos
# 65150  ...  Región Metropolitana de Santiago                 Pesos
# 65151  ...  Región Metropolitana de Santiago                 Pesos
# 65152  ...  Región Metropolitana de Santiago                 Pesos
#
#       remuneracionbruta remuliquida_mensual  pago_mensuales  \
# 50056            234000            210600.0              Sí
# 65149            799556                 NaN              Sí
# 65150           1400000                 NaN              Sí
# 65151            913778                 NaN              Sí
# 65152           1399222                 NaN              Sí
#
#                  fecha_ingreso fecha_termino    observaciones enlace viaticos
# 50056  2016/01/04 00:00:00.000    31/12/2016            SObs.     No      NaN
# 65149  2020/04/01 00:00:00.000    31/07/2020  Sin Observación     No      NaN
# 65150  2019/10/01 00:00:00.000    30/04/2020  Sin Observación     No      NaN
# 65151  2020/04/01 00:00:00.000    31/12/2020  Sin Observación     No      NaN
# 65152  2020/04/01 00:00:00.000    31/12/2020  Sin Observación     No      NaN
#
# [5 rows x 22 columns]

# %%
breakpoint()
